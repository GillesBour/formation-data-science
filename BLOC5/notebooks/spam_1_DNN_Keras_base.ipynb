# %% [markdown]
# ---
# # DNN : `spam` (avec `Keras`, version de base)
# ---

# %% [markdown]
# ## Packages

# %%
import pandas as pd

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from keras import layers, models
# Out:
# 2025-10-01 13:02:23.448402: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-01 13:02:23.515426: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-01 13:02:25.018132: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %% [markdown]
# ---
# ## 1. Données
# ---

# %% [markdown]
# ### 1.1. Importation

# %%
# En local :
directory = 'data/'

# Sur Google collab ou Onyxia (sur un répertoire temporaire) :
# directory = ''

# Sur Google collab (sur le drive) :
# from google.colab import drive
# drive.mount('/content/drive')
# directory = '/content/drive/MyDrive/Data/'

# %%
data = pd.read_csv(directory + 'spam.csv',
                   header    = 0,
                   # index_col = 0,
                   sep       = ',',
                   decimal   = '.')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4601 entries, 0 to 4600
# Data columns (total 58 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   word_freq_make              4601 non-null   float64
#  1   word_freq_address           4601 non-null   float64
#  2   word_freq_all               4601 non-null   float64
#  3   word_freq_3d                4601 non-null   float64
#  4   word_freq_our               4601 non-null   float64
#  5   word_freq_over              4601 non-null   float64
#  6   word_freq_remove            4601 non-null   float64
#  7   word_freq_internet          4601 non-null   float64
#  8   word_freq_order             4601 non-null   float64
#  9   word_freq_mail              4601 non-null   float64
#  10  word_freq_receive           4601 non-null   float64
#  11  word_freq_will              4601 non-null   float64
#  12  word_freq_people            4601 non-null   float64
#  13  word_freq_report            4601 non-null   float64
#  14  word_freq_addresses         4601 non-null   float64
#  15  word_freq_free              4601 non-null   float64
#  16  word_freq_business          4601 non-null   float64
#  17  word_freq_email             4601 non-null   float64
#  18  word_freq_you               4601 non-null   float64
#  19  word_freq_credit            4601 non-null   float64
#  20  word_freq_your              4601 non-null   float64
#  21  word_freq_font              4601 non-null   float64
#  22  word_freq_000               4601 non-null   float64
#  23  word_freq_money             4601 non-null   float64
#  24  word_freq_hp                4601 non-null   float64
#  25  word_freq_hpl               4601 non-null   float64
#  26  word_freq_george            4601 non-null   float64
#  27  word_freq_650               4601 non-null   float64
#  28  word_freq_lab               4601 non-null   float64
#  29  word_freq_labs              4601 non-null   float64
#  30  word_freq_telnet            4601 non-null   float64
#  31  word_freq_857               4601 non-null   float64
#  32  word_freq_data              4601 non-null   float64
#  33  word_freq_415               4601 non-null   float64
#  34  word_freq_85                4601 non-null   float64
#  35  word_freq_technology        4601 non-null   float64
#  36  word_freq_1999              4601 non-null   float64
#  37  word_freq_parts             4601 non-null   float64
#  38  word_freq_pm                4601 non-null   float64
#  39  word_freq_direct            4601 non-null   float64
#  40  word_freq_cs                4601 non-null   float64
#  41  word_freq_meeting           4601 non-null   float64
#  42  word_freq_original          4601 non-null   float64
#  43  word_freq_project           4601 non-null   float64
#  44  word_freq_re                4601 non-null   float64
#  45  word_freq_edu               4601 non-null   float64
#  46  word_freq_table             4601 non-null   float64
#  47  word_freq_conference        4601 non-null   float64
#  48  char_freq_semicolon         4601 non-null   float64
#  49  char_freq_leftbrac          4601 non-null   float64
#  50  char_freq_leftsquarebrac    4601 non-null   float64
#  51  char_freq_exclaim           4601 non-null   float64
#  52  char_freq_dollar            4601 non-null   float64
#  53  char_freq_pound             4601 non-null   float64
#  54  capital_run_length_average  4601 non-null   float64
#  55  capital_run_length_longest  4601 non-null   int64
#  56  capital_run_length_total    4601 non-null   int64
#  57  spam                        4601 non-null   int64
# dtypes: float64(55), int64(3)
# memory usage: 2.0 MB

# %%
data.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.00               0.64           0.64           0.0
# 1            0.21               0.28           0.50           0.0
# 2            0.06               0.00           0.71           0.0
# 3            0.00               0.00           0.00           0.0
# 4            0.00               0.00           0.00           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.32            0.00              0.00                0.00
# 1           0.14            0.28              0.21                0.07
# 2           1.23            0.19              0.19                0.12
# 3           0.63            0.00              0.31                0.63
# 4           0.63            0.00              0.31                0.63
#
#    word_freq_order  word_freq_mail  ...  char_freq_semicolon  \
# 0             0.00            0.00  ...                 0.00
# 1             0.00            0.94  ...                 0.00
# 2             0.64            0.25  ...                 0.01
# 3             0.31            0.63  ...                 0.00
# 4             0.31            0.63  ...                 0.00
#
#    char_freq_leftbrac  char_freq_leftsquarebrac  char_freq_exclaim  \
# 0               0.000                       0.0              0.778
# 1               0.132                       0.0              0.372
# 2               0.143                       0.0              0.276
# 3               0.137                       0.0              0.137
# 4               0.135                       0.0              0.135
#
#    char_freq_dollar  char_freq_pound  capital_run_length_average  \
# 0             0.000            0.000                       3.756
# 1             0.180            0.048                       5.114
# 2             0.184            0.010                       9.821
# 3             0.000            0.000                       3.537
# 4             0.000            0.000                       3.537
#
#    capital_run_length_longest  capital_run_length_total  spam
# 0                          61                       278     1
# 1                         101                      1028     1
# 2                         485                      2259     1
# 3                          40                       191     1
# 4                          40                       191     1
#
# [5 rows x 58 columns]

# %% [markdown]
# ### 1.2. Gestion des données manquantes

# %%
missing_percentage = data.isna().mean() * 100

print('MISSING VALUES :')
if missing_percentage[missing_percentage != 0].empty:
    print('No')
else:
    print(missing_percentage[missing_percentage != 0].sort_values(ascending=False))
# Out:
# MISSING VALUES :
# No

# %% [markdown]
# ### 1.3. Gestion des variables

# %%
target = 'spam'

y = data[target]
X = data.drop(target, axis=1)

# %% [markdown]
# ### 1.4. Création des échantillons de validation et test

# %%
test_portion  = 1/5
valid_portion = 1/5

X_train_valid, X_test, y_train_valid, y_test = train_test_split(X, y, test_size=test_portion)

X_train, X_valid, y_train, y_valid = train_test_split(X_train_valid, y_train_valid, test_size=valid_portion)

print('Dimensions de X_train :', X_train.shape)
print('Dimensions de X_valid :', X_valid.shape)
print('Dimensions de X_test  :', X_test.shape)

print('Dimensions de y_train :', y_train.shape)
print('Dimensions de y_valid :', y_valid.shape)
print('Dimensions de y_test  :', y_test.shape)
# Out:
# Dimensions de X_train : (2944, 57)
# Dimensions de X_valid : (736, 57)
# Dimensions de X_test  : (921, 57)
# Dimensions de y_train : (2944,)
# Dimensions de y_valid : (736,)
# Dimensions de y_test  : (921,)

# %% [markdown]
# ### 1.5. Normalisation des covariables

# %% [markdown]
# On normalise (centrage-réduction) les covariables :

# %%
scaler = StandardScaler()
scaler.fit(X_train)

X_train_norm = scaler.transform(X_train)
X_valid_norm = scaler.transform(X_valid)
X_test_norm  = scaler.transform(X_test)

# %% [markdown]
# ---
# ## 2. DNN
# ---

# %% [markdown]
# ### 2.1. Architecture

# %%
dim_inputs  = (X_train_norm.shape[1],)
dim_outputs = 1

n_units_hl1 = 50
n_units_hl2 = 30

model = models.Sequential(name='DNN')

model.add(layers.Input(shape=dim_inputs, name='Inputs'))

model.add(layers.Dense(units=n_units_hl1, activation='relu', name='Hidden_layer_1'))

model.add(layers.Dense(units=n_units_hl2, activation='relu', name='Hidden_layer_2'))

model.add(layers.Dense(units=dim_outputs, activation='sigmoid', name='Output_layer'))

model.summary()
# Out:
# 2025-10-01 13:02:25.349911: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "DNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Hidden_layer_1 (Dense)          │ (None, 50)             │         2,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden_layer_2 (Dense)          │ (None, 30)             │         1,530 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output_layer (Dense)            │ (None, 1)              │            31 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,461 (17.43 KB)
#  Trainable params: 4,461 (17.43 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 2.2. Optimiseur

# %%
model.compile(optimizer = 'adam',
              loss      = 'binary_crossentropy',
              metrics   = ['accuracy'])

# %% [markdown]
# ### 2.3. Entraînement

# %%
hist = model.fit(X_train_norm,
                 y_train,
                 batch_size      = 500,
                 epochs          = 200,
                 validation_data = (X_valid_norm, y_valid),
                 verbose         = 1)
# Out:
# Epoch 1/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.6736 - loss: 0.6369 - val_accuracy: 0.7459 - val_loss: 0.5953
# Epoch 2/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.7863 - loss: 0.5492 - val_accuracy: 0.8166 - val_loss: 0.5222
# Epoch 3/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.8468 - loss: 0.4854 - val_accuracy: 0.8492 - val_loss: 0.4628
# Epoch 4/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8747 - loss: 0.4329 - val_accuracy: 0.8764 - val_loss: 0.4111
# Epoch 5/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8855 - loss: 0.3864 - val_accuracy: 0.8886 - val_loss: 0.3666
# Epoch 6/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.8930 - loss: 0.3467 - val_accuracy: 0.8981 - val_loss: 0.3290
# Epoch 7/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9015 - loss: 0.3135 - val_accuracy: 0.9035 - val_loss: 0.2986
# Epoch 8/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9056 - loss: 0.2867 - val_accuracy: 0.9117 - val_loss: 0.2756
# Epoch 9/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9130 - loss: 0.2643 - val_accuracy: 0.9144 - val_loss: 0.2583
# Epoch 10/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9181 - loss: 0.2471 - val_accuracy: 0.9185 - val_loss: 0.2462
# Epoch 11/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9229 - loss: 0.2330 - val_accuracy: 0.9266 - val_loss: 0.2376
# Epoch 12/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9270 - loss: 0.2222 - val_accuracy: 0.9253 - val_loss: 0.2310
# Epoch 13/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9293 - loss: 0.2128 - val_accuracy: 0.9280 - val_loss: 0.2251
# Epoch 14/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9324 - loss: 0.2048 - val_accuracy: 0.9280 - val_loss: 0.2199
# Epoch 15/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9338 - loss: 0.1981 - val_accuracy: 0.9293 - val_loss: 0.2158
# Epoch 16/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9382 - loss: 0.1917 - val_accuracy: 0.9280 - val_loss: 0.2118
# Epoch 17/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9402 - loss: 0.1858 - val_accuracy: 0.9280 - val_loss: 0.2083
# Epoch 18/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9399 - loss: 0.1811 - val_accuracy: 0.9280 - val_loss: 0.2053
# Epoch 19/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.9409 - loss: 0.1760 - val_accuracy: 0.9293 - val_loss: 0.2029
# Epoch 20/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9419 - loss: 0.1713 - val_accuracy: 0.9307 - val_loss: 0.2005
# Epoch 21/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9433 - loss: 0.1672 - val_accuracy: 0.9321 - val_loss: 0.1984
# Epoch 22/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9443 - loss: 0.1632 - val_accuracy: 0.9321 - val_loss: 0.1960
# Epoch 23/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9443 - loss: 0.1595 - val_accuracy: 0.9293 - val_loss: 0.1947
# Epoch 24/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9457 - loss: 0.1560 - val_accuracy: 0.9293 - val_loss: 0.1931
# Epoch 25/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.
# Epoch 174/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9925 - loss: 0.0275 - val_accuracy: 0.9389 - val_loss: 0.2418
# Epoch 175/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9932 - loss: 0.0275 - val_accuracy: 0.9389 - val_loss: 0.2417
# Epoch 176/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9935 - loss: 0.0271 - val_accuracy: 0.9389 - val_loss: 0.2432
# Epoch 177/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.9932 - loss: 0.0268 - val_accuracy: 0.9389 - val_loss: 0.2436
# Epoch 178/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9935 - loss: 0.0263 - val_accuracy: 0.9375 - val_loss: 0.2444
# Epoch 179/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.9929 - loss: 0.0260 - val_accuracy: 0.9389 - val_loss: 0.2450
# Epoch 180/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9935 - loss: 0.0262 - val_accuracy: 0.9389 - val_loss: 0.2464
# Epoch 181/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9932 - loss: 0.0254 - val_accuracy: 0.9389 - val_loss: 0.2465
# Epoch 182/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.9932 - loss: 0.0251 - val_accuracy: 0.9389 - val_loss: 0.2474
# Epoch 183/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9925 - loss: 0.0250 - val_accuracy: 0.9375 - val_loss: 0.2475
# Epoch 184/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9942 - loss: 0.0246 - val_accuracy: 0.9389 - val_loss: 0.2487
# Epoch 185/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.9939 - loss: 0.0244 - val_accuracy: 0.9389 - val_loss: 0.2485
# Epoch 186/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9935 - loss: 0.0245 - val_accuracy: 0.9375 - val_loss: 0.2506
# Epoch 187/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9932 - loss: 0.0238 - val_accuracy: 0.9389 - val_loss: 0.2507
# Epoch 188/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.9939 - loss: 0.0236 - val_accuracy: 0.9389 - val_loss: 0.2526
# Epoch 189/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9939 - loss: 0.0235 - val_accuracy: 0.9375 - val_loss: 0.2518
# Epoch 190/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9932 - loss: 0.0234 - val_accuracy: 0.9389 - val_loss: 0.2536
# Epoch 191/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9932 - loss: 0.0232 - val_accuracy: 0.9375 - val_loss: 0.2558
# Epoch 192/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9942 - loss: 0.0225 - val_accuracy: 0.9389 - val_loss: 0.2558
# Epoch 193/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.9939 - loss: 0.0225 - val_accuracy: 0.9361 - val_loss: 0.2567
# Epoch 194/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9942 - loss: 0.0221 - val_accuracy: 0.9375 - val_loss: 0.2587
# Epoch 195/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9939 - loss: 0.0222 - val_accuracy: 0.9361 - val_loss: 0.2577
# Epoch 196/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9939 - loss: 0.0222 - val_accuracy: 0.9402 - val_loss: 0.2597
# Epoch 197/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.9939 - loss: 0.0221 - val_accuracy: 0.9361 - val_loss: 0.2628
# Epoch 198/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.9935 - loss: 0.0228 - val_accuracy: 0.9375 - val_loss: 0.2610
# Epoch 199/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9939 - loss: 0.0217 - val_accuracy: 0.9361 - val_loss: 0.2655
# Epoch 200/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.9929 - loss: 0.0217 - val_accuracy: 0.9416 - val_loss: 0.2633

# %%
fig, ax = plt.subplots(figsize=(10, 7))
ax.plot(hist.history['loss'], label='Train')
ax.plot(hist.history['val_loss'], label='Validation')
ax.set_xlabel('Epoque')
ax.set_title('Entropie')
ax.legend(loc='best')
plt.show()

# %% [markdown]
# Pas bon, on a surappris. Ce code n'est pas utilisable. Il faut ajouter un callback.

# %%
fig, ax = plt.subplots(figsize=(10, 7))
ax.plot(hist.history['accuracy'], label='Train')
ax.plot(hist.history['val_accuracy'], label='Validation')
ax.set_xlabel('Epoque')
ax.set_title('Exactitude (accuracy)')
ax.legend(loc='best')
plt.show()

# %% [markdown]
# ### 2.4. Prévisions

# %%
y_test_pred = model.predict(X_test_norm)
y_test_pred[0:5]
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# array([[3.4081182e-01],
#        [4.4553679e-01],
#        [2.0342704e-05],
#        [4.4053065e-25],
#        [1.6725179e-03]], dtype=float32)

# %%
y_test_pred_classes = (y_test_pred > 0.5).astype(int)
y_test_pred_classes[0:5]
# Out:
# array([[0],
#        [0],
#        [0],
#        [0],
#        [0]])

# %%
score_test = model.evaluate(X_test_norm, y_test, verbose=0)
print(f'Entropie test   : {score_test[0]:4.4f}')
print(f'Exactitude test : {score_test[1]:4.4f}')
# Out:
# Entropie test   : 0.2850
# Exactitude test : 0.9359
