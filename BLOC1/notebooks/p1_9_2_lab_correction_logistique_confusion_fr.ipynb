# %% [markdown]
# <div class="licence">
# <span>Lisa BEDIN<br />Pierre André CORNILLON<br />Eric MATZNER-LOBER</span>
# <span>Licence CC BY-NC-ND</span>
# </div>
#
# # Modules python
#
# Importer les modules pandas (comme `pd`) numpy (commme `np`) matplotlib.pyplot (comme `plt`) et statsmodels.formula.api (comme `smf`).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# %% [markdown]
# # Régression logistique (suite TP précédent)
#
#
# ## Importation des données
#
# Importer les données `artere.txt` dans le DataFrame pandas `artere` \[`read_csv` de `numpy` \]. Sur Fun Campus le chemin est `data/artere.txt`. Outre l'age et la présence=1/absence=0 de la maladie cardio-vasculaire (`chd`) une variable qualitative à 8 modalités donne les classes d'age (`agegrp`)

# %%
artere = pd.read_csv("data/artere.txt", header=0, sep=" ")

# %% [markdown]
# ## Régression logistique
#
# Effectuer une régression logistique où `age` est la variable explicative et `chd` la variable binaire à expliquer. Stocker le résultat dans l'objet `modele`
#
# \[`logit` de `smf`, méthode `fit` \]

# %%
modele = smf.logit('chd~age', data=artere).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.536765
#          Iterations 6

# %% [markdown]
# ## Matrice de confusion (ajustée)
#
# Afficher la matrice de confusion estimée sur les données de l'échantillon pour un seuil choisi à 0.5.
#
# Une méthode manuelle est la suivante

# %%
yhat = modele.predict()>0.5
df = pd.DataFrame({"yhat" : yhat, "chd": artere.chd})
pd.crosstab(index=df['chd'], columns=df['yhat'])
# Out:
# yhat  False  True
# chd
# 0        45     12
# 1        14     29

# %% [markdown]
# mais il existe aussi une fonction adptée uniquement à l'estimation de la matrice de confusion en ajustement:

# %%
modele.pred_table(threshold=0.5)
# Out:
# array([[45., 12.],
#        [14., 29.]])

# %% [markdown]
# Attention cette matrice de confusion est ajustée et reste donc très optimiste. Une matrice de confusion calculée par validation croisée ou apprentissage/validation est plus que conseillée !
#
#
# ## Résidus
#
# Représenter graphiquement les résidus de déviance avec
#
# 1.  en abscisse la variable `age` et en ordonnée les résidus \[attribut `resid_dev` du modèle\];
# 2.  en abscisse le numéro de ligne du tableau (index) après permutation aléatoire et en ordonnées les résidus.
#
# \[`plt.plot`, méthode `predict` pour l'instance/modèle ajusté et `np.arange` pour générer les numéros de ligne avec l'attribut `shape` du DataFrame ; créer une instance de générateur aléatoire `np.random.default_rng` et utiliser `rng.permutation` sur les numéros de ligne\]

# %%
plt.plot(artere.age, modele.resid_dev, "+")
plt.show()

# %% [markdown]
# Nous retrouvons l'allure caractéristique du graphique résidus fonction de $\hat p$ (ou de l'age ici). Ce type de graphique n'est pas utilisé en pratique.

# %%
rng = np.random.default_rng(seed=1234)
indexp = rng.permutation(np.arange(artere.shape[0]))
plt.plot(indexp, modele.resid_dev, "+")
plt.show()

# %% [markdown]
# Aucune observation avec des valeurs extrêmes, le modèle ajuste bien les données.
#
#
# ## Matrice de confusion (en prévision)
#
# Ayant peu de données ici plutôt que d'évaluer la matrice de confusion en apprentissage/validation nous choisissons (contraints et forcés) d'évaluer celle-ci en validation croisée.
#
#
# ### Séparation en 10 blocs
#
# Nous allons séparer le jeu de données en 10 blocs grâce à la fonction [StratifiedKFold](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedKFold.html#sklearn.model_selection.StratifiedKFold) (du module `sklearn` sous module `model_selection`) créer une instance de `StratifiedKFold` nommée `skf`.

# %%
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=0)

# %% [markdown]
# Cela permet d'obtenir une répartition 0/1 quasiment identique de blocs en blocs. En effet la proportion de 1 dans chaque bloc de validation est ici:

# %%
y = artere.chd.values
X = artere.values
for app_index, val_index in skf.split(X,y):
    print(val_index)
    print(artere.chd.iloc[val_index].mean())
# Out:
# [ 4  6 11 32 49 79 80 82 84 91]
# 0.4
# [ 5 12 19 40 50 57 67 71 93 98]
# 0.4
# [20 30 31 34 41 43 52 58 76 88]
# 0.4
# [ 9 26 37 44 59 63 65 78 83 94]
# 0.4
# [ 3 13 15 23 29 42 56 61 87 95]
# 0.4
# [ 0  1  7 16 21 22 28 33 75 81]
# 0.4
# [ 2 17 18 48 51 62 64 68 77 86]
# 0.4
# [24 38 45 46 54 55 60 66 92 96]
# 0.5
# [14 25 35 36 39 72 74 89 90 99]
# 0.5
# [ 8 10 27 47 53 69 70 73 85 97]
# 0.5

# %% [markdown]
# ### DataFrame prevision et $chd$
#
# Créer un DataFrame `res` avec deux colonnes: la variable $chd$ et une second colonne remplie de 0 qui contiendra les prévisions. Cette colonne pourra être nommée `yhat`

# %%
res = pd.DataFrame(artere.chd)
res["yhat"] = 0

# %% [markdown]
# Ajouter au fur et à mesure les prévisions en validation croisée dans la deuxième colonne: Pour chaque «tour» de bloc faire
#
# 1.  estimer sur les 9 blocs en apprentissage le modèle de régression logistique
# 2.  prévoir les données du bloc en validation (seuil $s=1/2$)
# 3.  ranger dans les lignes correspondantes de `res` les prévisions (dans la colonne `yhat`)

# %%
y = artere.chd.values
X = artere.iloc[:,0:2].values
s = 0.5
for app_index, val_index in skf.split(X,y):
    artereapp=artere.iloc[app_index,:]
    artereval=artere.iloc[val_index,:]
    modele = smf.logit('chd~age', data=artereapp).fit()
    res.iloc[val_index,1] = modele.predict(exog=artereval)>s
# Out:
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6

# %% [markdown]
# ### Calculer la matrice de confusion
#
# Avec la fonction `crosstab` du module `pd` proposer la matrice de confusion estimée par validation croisée. En déduire la spécifité et la sensibilité.

# %%
print(pd.crosstab(index=res['chd'], columns=res['yhat']))
# Out:
# yhat  False  True
# chd
# 0        45     12
# 1        15     28

# %% [markdown]
# ## Choix d'un seuil
#
# Un test physique réalise une sensibilité de 50% et pour cette sensibilité une spécifité de $90\%$. Choisir le seuil pour une sensibilité de 50% (en validation croisée 10 blocs) et donner la spécifité correspondante.

# %%
sall = np.linspace(0, 1 , 100)
res = np.zeros((artere.shape[0], len(sall)+1))
res[:,0] = artere.chd.values
res = pd.DataFrame(res)
res.rename(columns={res.columns[0] : "chd"}, inplace=True)
for i,s in enumerate(sall):
    for app_index, val_index in skf.split(X,y):
        artereapp=artere.iloc[app_index,:]
        artereval=artere.iloc[val_index,:]
        modele = smf.logit('chd~age', data=artereapp).fit()
        res.iloc[val_index,i+1] = modele.predict(exog=artereval)>s
# Out:
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
# ...
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541285
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541938
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542914
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529667
#          Iterations 6

# %% [markdown]
# On calcule pour chaque seuil les matrices de confusion (attention au cas où le modèle ne prévoit que des "0" ou que des "1").
#
# De tous les seuils qui dépassent 0.5 de sensibilité prenons le plus grand:

# %%
confusion = pd.DataFrame(np.zeros((len(sall),2)))
for i,s in enumerate(sall):
    tab = pd.crosstab(index=res['chd'], columns=res.iloc[:,i+1])
    if tab.shape[1]==1:
        if tab.columns[0]:
            confusion.iloc[i, 0]=0
            confusion.iloc[i, 1]=1
        else:
            confusion.iloc[i, 0]=1
            confusion.iloc[i, 1]=0
    else:
        confusion.iloc[i, 0] = tab.iloc[0,0]/ tab.iloc[0,:].sum()
        confusion.iloc[i, 1] = tab.iloc[1,1]/ tab.iloc[1,:].sum()

print(sall[confusion.loc[confusion.iloc[:,1]>=0.5].shape[0]])
# Out:
# 0.6666666666666667

# %% [markdown]
# Ce modèle d'age permet ici un sensibilité de 0.5 et presque 0.9 de spécifité.
#
#
# # Choix de variables
#
#
# ## Importation des données
#
# Importation des données d'ozone `spambase.data` (dans Fun Campus les données sont dans le répertoire `data/`)

# %%
spam = pd.read_csv("data/spambase.data", header=None,  sep=",")
spam.rename(columns={spam.columns[57] : "Y"}, inplace=True)
namestr = ["X"+str(i) for i in spam.columns[0:57] ]
spam.rename(columns= dict(zip(list(spam.columns[0:57]), namestr)), inplace=True)

# %% [markdown]
# ## Sélection descendante/backward
#
# Nous reprenons le code de sélection descendante sur la régression et nous remplaçons simplement le mot `ols` par `logit`
#
# La fonction commence avec le modèle complet.
#
# -   Nous séparons la variable réponse (objet `response`) des variables explicatives,
# -   Ces dernières sont transformées en un ensemble (objet `start_explanatory`),
# -   L'ensemble le plus petit est l'ensemble vide (objet `lower_explanatory`),
# -   Les variables potentielles à supprimer sont obtenues par différence (objet `remove`),
#
# Nous initialisons l'ensemble des variables sélectionnées (objet `selected`) et réalisons notre première formule en utilisant toutes les variables sélectionnées. En utilisant `smf.logit` nous obtenons l'AIC ou le BIC du modèle de départ (`current_score`).
#
# La boucle while commence :
#
# -   pour chaque variable (boucle for) à supprimer, nous effectuons une régression avec l'ensemble actuel des variables moins cette variable candidate. Nous construisons une liste de triplets `score` (AIC/BIC), signe (toujours "-" car nous effectuons une sélection backward) et la variable candidate à supprimer du modèle actuel.
#
# -   A la fin de la boucle for, nous trions toute la liste des triplets en utilisant le score et si le meilleur triplet a un `score` meilleur que `current_score` nous mettons à jour `remove`, `selected` et `current_score`, si ce n'est pas le cas, nous interrompons la boucle while.
#
# A la fin, nous ajustons le modèle actuel et le renvoyons comme résultat.

# %%
def logitbackward(data, start, crit="aic", verbose=False):
    """Backward selection for linear model with smf (with formula).

    Parameters:
    -----------
    data (pandas DataFrame): DataFrame with all possible predictors
            and response
    start (string): a string giving the starting model
            (ie the starting point)
    crit (string): "aic"/"AIC" or "bic"/"BIC"
    verbose (boolean): if True verbose print

    Returns:
    --------
    model: an "optimal" linear model fitted with statsmodels
           with an intercept and
           selected by forward/backward or both algorithm with crit criterion
    """
    # criterion
    if not (crit == "aic" or crit == "AIC" or crit == "bic" or crit == "BIC"):
        raise ValueError("criterion error (should be AIC/aic or BIC/bic)")
    # starting point
    formula_start = start.split("~")
    response = formula_start[0].strip()
    # explanatory variables for the 3 models
    start_explanatory = set([item.strip() for item in
                             formula_start[1].split("+")]) - set(['1'])
    # setting up the set "remove" which contains the possible
    # variable to remove
    lower_explanatory = set([])
    remove = start_explanatory - lower_explanatory
    # current point
    selected = start_explanatory
    formula = "{} ~ {} + 1".format(response,
                                   ' + '.join(list(selected)))
    if crit == "aic" or crit == "AIC":
        current_score = smf.logit(formula, data).fit().aic
    elif crit == "bic" or crit == "BIC":
        current_score = smf.logit(formula, data).fit().bic
    if verbose:
        print("----------------------------------------------")
        print((current_score, "Starting", selected))
    # main loop
    while True:
        scores_with_candidates = []
        for candidate in remove:
            tobetested = selected - set([candidate])
            formula = "{} ~ {} + 1".format(response,
                                           ' + '.join(list(tobetested)))
            if crit == "aic" or crit == "AIC":
                score = smf.logit(formula, data).fit().aic
            elif crit == "bic" or crit == "BIC":
                score = smf.logit(formula, data).fit().bic
            if verbose:
                print((score, "-", candidate))
            scores_with_candidates.append((score, candidate))
        scores_with_candidates.sort()
        best_new_score, best_candidate = scores_with_candidates.pop(0)
        if current_score > best_new_score:
            remove = remove - set([best_candidate])
            selected = selected - set([best_candidate])
            current_score = best_new_score
            if verbose:
                print("----------------------------------------------")
                print((current_score, "New Current", selected))
        else:
            break
    if verbose:
        print("----------------------------------------------")
        print((current_score, "Final", selected))
    formula = "{} ~ {} + 1".format(response, ' + '.join(list(selected)))
    model = smf.logit(formula, data).fit()
    return model

# %% [markdown]
# La mise en oeuvre

# %%
modelefinal = logitbackward(spam,"Y~X0+X1+X2+X3+X4+X5+X6+X7+X8+X9+X10+X11+X12+X13+X14+X15+X16+X17+X18+X19+X20+X21+X22+X23+X24+X25+X26+X27+X28+X29+X30+X31+X32+X33+X34+X35+X36+X37+X38+X39+X40+X41+X42+X43+X44+X45+X46+X47+X48+X49+X50+X51+X52+X53+X54+X55+X56", verbose=True)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.197323
#          Iterations 15
# ----------------------------------------------
# (1931.765477498958, 'Starting', {'X35', 'X51', 'X45', 'X46', 'X27', 'X39', 'X0', 'X43', 'X3', 'X7', 'X56', 'X26', 'X18', 'X32', 'X48', 'X16', 'X1', 'X21', 'X29', 'X55', 'X24', 'X4', 'X40', 'X22', 'X14', 'X28', 'X13', 'X5', 'X50', 'X53', 'X15', 'X38', 'X10', 'X12', 'X17', 'X30', 'X47', 'X19', 'X41', 'X25', 'X2', 'X9', 'X36', 'X31', 'X11', 'X33', 'X42', 'X52', 'X8', 'X34', 'X44', 'X49', 'X23', 'X6', 'X20', 'X37', 'X54'})
# Optimization terminated successfully.
#          Current function value: 0.198263
#          Iterations 15
# (1938.414592932064, '-', 'X35')
# Optimization terminated successfully.
#          Current function value: 0.200583
#          Iterations 15
# (1959.7634487069186, '-', 'X51')
# Optimization terminated successfully.
#          Current function value: 0.204681
#          Iterations 15
# (1997.4780468512686, '-', 'X45')
# Optimization terminated successfully.
#          Current function value: 0.197834
#          Iterations 15
# (1934.4675212237591, '-', 'X46')
# Optimization terminated successfully.
#          Current function value: 0.198121
#          Iterations 15
# (1937.1076397642846, '-', 'X27')
# Optimization terminated successfully.
#          Current function value: 0.197409
#          Iterations 15
# (1930.553697038287, '-', 'X39')
# Optimization terminated successfully.
#          Current function value: 0.197662
#          Iterations 15
# (1932.8866078075032, '-', 'X0')
# Optimization terminated successfully.
#          Current function value: 0.199385
#          Iterations 15
# (1948.7402056336848, '-', 'X43')
# Optimization terminated successfully.
#          Current function value: 0.198314
#          Iterations 15
# (1938.8855175048757, '-', 'X3')
# Optimization terminated successfully.
#          Current function value: 0.199208
#          Iterations 15
# (1947.109044085149, '-', 'X7')
# Optimization terminated successfully.
#          Current function value: 0.199514
#          Iterations 16
# (1949.927596615421, '-', 'X56')
# Optimization terminated successfully.
#          Current function value: 0.223798
#          Iterations 15
# (2173.3897286299434, '-', 'X26')
# Optimization terminated successfully.
#          Current function value: 0.197896
#          Iterations 15
# (1935.040292780181, '-', 'X18')
# Optimization terminated successfully.
#          Current function value: 0.198530
#          Iterations 15
# (1940.8762596468844, '-', 'X32')
# Optimization terminated successfully.
#          Current function value: 0.199236
#          Iterations 15
# (1947.366733929803, '-', 'X48')
# Optimization terminated successfully.
#          Current function value: 0.199826
#          Iterations 16
# (1952.7966984684836, '-', 'X16')
# Optimization terminated successfully.
#          Current function value: 0.198218
#          Iterations 15
# (1938.0023014462872, '-', 'X1')
# Optimization terminated successfully.
#          Current function value: 0.197540
#          Iterations 15
# (1931.7621756487788, '-', 'X21')
# Optimization terminated successfully.
#          Current function value: 0.197457
#          Iterations 15
# (1931.0039046211307, '-', 'X29')
# Optimization terminated successfully.
#          Current function value: 0.198868
#          Iterations 15
# (1943.982808870272, '-', 'X55')
# Optimization terminated successfully.
#          Current function value: 0.210604
#          Iterations 16
# (2051.9804222047287, '-', 'X24')
# Optimization terminated successfully.
#          Current function value: 0.201534
#          Iterations 15
# (1968.5174771752272, '-', 'X4')
# Optimization terminated successfully.
#          Current function value: 0.200093
#          Iterations 14
# (1955.2599822173156, '-', 'X40')
# Optimization terminated successfully.
#          Current function value: 0.201833
#          Iterations 15
# (1971.2678440594598, '-', 'X22')
# Optimization terminated successfully.
#          Current function value: 0.197715
#          Iterations 15
# (1933.372761630183, '-', 'X14')
# Optimization terminated successfully.
#          Current function value: 0.198436
#          Iterations 15
# (1940.006763226217, '-', 'X28')
# Optimization terminated successfully.
#          Current function value: 0.197439
#          Iterations 15
# (1930.8356819219784, '-', 'X13')
# Optimization terminated successfully.
#          Current function value: 0.199018
#          Iterations 15
# (1945.3630060095775, '-', 'X5')
# Optimization terminated successfully.
#          Current function value: 0.197431
#          Iterations 15
# (1930.7610852302482, '-', 'X50')
# Optimization terminated successfully.
#          Current function value: 0.198030
#          Iterations 15
# (1936.2734980686323, '-', 'X53')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.207162
#          Iterations: 35
# (2020.3016880691973, '-', 'X15')
# Optimization terminated successfully.
#          Current function value: 0.198128
#          Iterations 15
# (1937.1772493533572, '-', 'X38')
# Optimization terminated successfully.
#          Current function value: 0.197404
#          Iterations 15
# (1930.509415790663, '-', 'X10')
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Optimization terminated successfully.
#          Current function value: 0.197336
#          Iterations 15
# (1929.8857348212362, '-', 'X12')
# Optimization terminated successfully.
#          Current function value: 0.197439
#          Iterations 15
# (1930.829244455025, '-', 'X17')
# Optimization terminated successfully.
#          Current function value: 0.197350
#          Iterations 15
# (1930.0166134022593, '-', 'X30')
# Optimization terminated successfully.
#          Current function value: 0.199167
#          Iterations 15
# (1946.732678129473, '-', 'X47')
# Optimization terminated successfully.
#          Current function value: 0.198647
#          Iterations 15
# (1941.947412889645, '-', 'X19')
# Optimization terminated successfully.
#          Current function value: 0.202980
#          Iterations 15
# (1981.824853499541, '-', 'X41')
# Optimization terminated successfully.
#          Current function value: 0.198213
#          Iterations 15
# (1937.9581000224944, '-', 'X25')
# Optimization terminated successfully.
#          Current function value: 0.197438
#          Iterations 15
# (1930.8198824465871, '-', 'X2')
# Optimization terminated successfully.
#          Current function value: 0.197684
#          Iterations 15
# (1933.090416129342, '-', 'X9')
# Optimization terminated successfully.
#          Current function value: 0.197330
#          Iterations 15
# (1929.8351001472465, '-', 'X36')
# Optimization terminated successfully.
#          Current function value: 0.197395
#          Iterations 15
# (1930.4262554493412, '-', 'X31')
# Optimization terminated successfully.
#          Current function value: 0.197731
#          Iterations 15
# (1933.5251301914452, '-', 'X11')
# Optimization terminated successfully.
#          Current function value: 0.197344
#          Iterations 15
# (1929.9554145845098, '-', 'X33')
# Optimization terminated successfully.
#          Current function value: 0.197830
#          Iterations 15
# (1934.4280693866808, '-', 'X42')
# Optimization terminated successfully.
#          Current function value: 0.207038
#          Iterations 15
# (2019.1660705338506, '-', 'X52')
# Optimization terminated successfully.
#          Current function value: 0.198092
#          Iterations 15
# (1936.8427858311634, '-', 'X8')
# Optimization terminated successfully.
#          Current function value: 0.198263
#          Iterations 15
# (1938.4128597855013, '-', 'X34')
# Optimization terminated successfully.
#          Current function value: 0.202568
#          Iterations 16
# (1978.0271603255367, '-', 'X44')
# Optimization terminated successfully.
#          Current function value: 0.197390
#          Iterations 15
# (1930.3783575478503, '-', 'X49')
# Optimization terminated successfully.
#          Current function value: 0.198639
#          Iterations 15
# (1941.879191958432, '-', 'X23')
# Optimization terminated successfully.
#          Current function value: 0.208294
#          Iterations 15
# (2030.7250848198717, '-', 'X6')
# Optimization terminated successfully.
#          Current function value: 0.199733
#          Iterations 15
# (1951.9441748790232, '-', 'X20')
# Optimization terminated successfully.
#          Current function value: 0.197713
#          Iterations 15
# (1933.3570313060195, '-', 'X37')
# Optimization terminated successfully.
#          Current function value: 0.197368
#          Iterations 15
# (1930.1812184350429, '-', 'X54')
# ----------------------------------------------
# (1929.8351001472465, 'New Current', {'X35', 'X51', 'X45', 'X46', 'X27', 'X39', 'X0', 'X43', 'X3', 'X7', 'X56', 'X26', 'X18', 'X32', 'X48', 'X16', 'X1', 'X21', 'X29', 'X55', 'X24', 'X4', 'X40', 'X22', 'X14', 'X28', 'X13', 'X5', 'X50', 'X53', 'X15', 'X38', 'X10', 'X12', 'X17', 'X30', 'X47', 'X19', 'X41', 'X25', 'X2', 'X9', 'X31', 'X11', 'X33', 'X42', 'X52', 'X8', 'X34', 'X44', 'X49', 'X23', 'X6', 'X20', 'X37', 'X54'})
# Optimization terminated successfully.
#          Current function value: 0.198266
#          Iterations 15
# (1936.4394549500325, '-', 'X35')
# Optimization terminated successfully.
#          Current function value: 0.200592
#          Iterations 15
# (1957.8486969651797, '-', 'X51')
# Optimization terminated successfully.
#          Current function value: 0.204726
#          Iterations 15
# (1995.891349765169, '-', 'X45')
# Optimization terminated successfully.
#          Current function value: 0.197843
#          Iterations 15
# (1932.546764401594, '-', 'X46')
# Optimization terminated successfully.
#          Current function value: 0.198123
#          Iterations 15
# (1935.1270261310246, '-', 'X27')
# Optimization terminated successfully.
#          Current function value: 0.197417
#          Iterations 15
# (1928.6276504954085, '-', 'X39')
# Optimization terminated successfully.
#          Current function value: 0.197669
#          Iterations 15
# (1930.948490967942, '-', 'X0')
# Optimization terminated successfully.
#          Current function value: 0.199396
#          Iterations 15
# (1946.842390321266, '-', 'X43')
# Optimization terminated successfully.
#          Current function value: 0.198319
#          Iterations 15
# (1936.9348638122633, '-', 'X3')
# Optimization terminated successfully.
#          Current function value: 0.199214
#          Iterations 15
# (1945.163570118029, '-', 'X7')
# Optimization terminated successfully.
#          Current function value: 0.199534
#          Iterations 16
# (1948.1091894151466, '-', 'X56')
# Optimization terminated successfully.
#          Current function value: 0.223801
#          Iterations 15
# (2171.4208808409, '-', 'X26')
# Optimization terminated successfully.
#          Current function value: 0.197899
#          Iterations 15
# (1933.0689574966086, '-', 'X18')
# Optimization terminated successfully.
#          Current function value: 0.198532
#          Iterations 15
# (1938.8937999004334, '-', 'X32')
# Optimization terminated successfully.
#          Current function value: 0.199237
#          Iterations 15
# (1945.3743425385453, '-', 'X48')
# Optimization terminated successfully.
#          Current function value: 0.199833
#          Iterations 16
# (1950.8595888793202, '-', 'X16')
# Optimization terminated successfully.
#          Current function value: 0.198232
#          Iterations 15
# (1936.1264946338135, '-', 'X1')
# Optimization terminated successfully.
#          Current function value: 0.197544
#          Iterations 15
# (1929.8026244883972, '-', 'X21')
# Optimization terminated successfully.
#          Current function value: 0.197464
#          Iterations 15
# (1929.0659923720527, '-', 'X29')
# Optimization terminated successfully.
#          Current function value: 0.198870
#          Iterations 15
# (1942.003211016832, '-', 'X55')
# Optimization terminated successfully.
#          Current function value: 0.210604
#          Iterations 16
# (2049.9809514151366, '-', 'X24')
# Optimization terminated successfully.
#          Current function value: 0.201541
#          Iterations 15
# (1966.5760274990614, '-', 'X4')
# Optimization terminated successfully.
#          Current function value: 0.200102
#          Iterations 14
# (1953.3410731375914, '-', 'X40')
# Optimization terminated successfully.
#          Current function value: 0.201841
#          Iterations 15
# (1969.3406956220513, '-', 'X22')
# Optimization terminated successfully.
#          Current function value: 0.197723
#          Iterations 15
# (1931.4490458466676, '-', 'X14')
# Optimization terminated successfully.
#          Current function value: 0.198445
#          Iterations 15
# (1938.0899431280668, '-', 'X28')
# Optimization terminated successfully.
#          Current function value: 0.197447
#          Iterations 15
# (1928.903759862998, '-', 'X13')
# Optimization terminated successfully.
#          Current function value: 0.199025
#          Iterations 15
# (1943.4274781581335, '-', 'X5')
# Optimization terminated successfully.
#          Current function value: 0.197440
#          Iterations 15
# (1928.839041979019, '-', 'X50')
# Optimization terminated successfully.
#          Current function value: 0.198039
#          Iterations 15
# (1934.357486206185, '-', 'X53')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.212595
#          Iterations: 35
# (2068.3025844957638, '-', 'X15')
# Optimization terminated successfully.
#          Current function value: 0.198131
#          Iterations 15
# (1935.202602466451, '-', 'X38')
# Optimization terminated successfully.
#          Current function value: 0.197410
#          Iterations 15
# (1928.5710792214568, '-', 'X10')
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Optimization terminated successfully.
#          Current function value: 0.197344
#          Iterations 15
# (1927.9639694411248, '-', 'X12')
# Optimization terminated successfully.
#          Current function value: 0.197445
#          Iterations 15
# (1928.8857642973353, '-', 'X17')
# Optimization terminated successfully.
#          Current function value: 0.197358
#          Iterations 15
# (1928.086644889498, '-', 'X30')
# Optimization terminated successfully.
#          Current function value: 0.199168
#          Iterations 15
# (1944.7408810142879, '-', 'X47')
# Optimization terminated successfully.
#          Current function value: 0.198653
#          Iterations 15
# (1940.0077677943386, '-', 'X19')
# Optimization terminated successfully.
#          Current function value: 0.202993
#          Iterations 15
# (1979.9419304342441, '-', 'X41')
# Optimization terminated successfully.
#          Current function value: 0.198216
#          Iterations 15
# (1935.9808681758207, '-', 'X25')
# Optimization terminated successfully.
#          Current function value: 0.197446
#          Iterations 15
# (1928.8968687152949, '-', 'X2')
# Optimization terminated successfully.
#          Current function value: 0.197690
#          Iterations 15
# (1931.1449613454806, '-', 'X9')
# Optimization terminated successfully.
#          Current function value: 0.197402
#          Iterations 15
# (1928.4903799724136, '-', 'X31')
# Optimization terminated successfully.
#          Current function value: 0.197742
#          Iterations 15
# (1931.6177336400265, '-', 'X11')
# Optimization terminated successfully.
#          Current function value: 0.197351
#          Iterations 15
# (1928.0240157165258, '-', 'X33')
# Optimization terminated successfully.
#          Current function value: 0.197831
#          Iterations 15
# (1932.4365597515605, '-', 'X42')
# Optimization terminated successfully.
#          Current function value: 0.207047
#          Iterations 15
# (2017.242117153971, '-', 'X52')
# Optimization terminated successfully.
#          Current function value: 0.198096
#          Iterations 15
# (1934.883235799296, '-', 'X8')
# Optimization terminated successfully.
#          Current function value: 0.198268
#          Iterations 15
# (1936.4621495123988, '-', 'X34')
# Optimization terminated successfully.
#          Current function value: 0.202582
#          Iterations 16
# (1976.163211921821, '-', 'X44')
# Optimization terminated successfully.
#          Current function value: 0.197394
#          Iterations 15
# (1928.4232728148852, '-', 'X49')
# Optimization terminated successfully.
#          Current function value: 0.198644
#          Iterations 15
# (1939.91832160331, '-', 'X23')
# Optimization terminated successfully.
#          Current function value: 0.208295
#          Iterations 15
# (2028.7262722071723, '-', 'X6')
# Optimization terminated successfully.
#          Current function value: 0.199733
#          Iterations 15
# (1949.9442714201969, '-', 'X20')
# Optimization terminated successfully.
#          Current function value: 0.197721
#          Iterations 15
# (1931.4290101163701, '-', 'X37')
# Optimization terminated successfully.
#          Current function value: 0.197377
#          Iterations 15
# (1928.2586382857842, '-', 'X54')
# ----------------------------------------------
# (1927.9639694411248, 'New Current', {'X35', 'X51', 'X45', 'X46', 'X27', 'X39', 'X0', 'X43', 'X3', 'X7', 'X56', 'X26', 'X18', 'X32', 'X48', 'X16', 'X1', 'X21', 'X29', 'X55', 'X24', 'X4', 'X40', 'X22', 'X14', 'X28', 'X13', 'X5', 'X50', 'X53', 'X15', 'X38', 'X10', 'X17', 'X30', 'X47', 'X19', 'X41', 'X25', 'X2', 'X9', 'X31', 'X11', 'X33', 'X42', 'X52', 'X8', 'X34', 'X44', 'X49', 'X23', 'X6', 'X20', 'X37', 'X54'})
# Optimization terminated successfully.
#          Current function value: 0.198285
#          Iterations 15
# (1934.6142694139614, '-', 'X35')
# Optimization terminated successfully.
#          Current function value: 0.200609
#          Iterations 15
# (1956.005499626588, '-', 'X51')
# Optimization terminated successfully.
#          Current function value: 0.204781
#          Iterations 15
# (1994.3988114834347, '-', 'X45')
# Optimization terminated successfully.
#          Current function value: 0.197856
#          Iterations 15
# (1930.670341778314, '-', 'X46')
# Optimization terminated successfully.
#          Current function value: 0.198139
#          Iterations 15
# (1933.2774708404393, '-', 'X27')
# Optimization terminated successfully.
#          Current function value: 0.197431
#          Iterations 15
# (1926.7575495974415, '-', 'X39')
# Optimization terminated successfully.
#          Current function value: 0.197686
#          Iterations 15
# (1929.1083985411278, '-', 'X0')
# Optimization terminated successfully.
#          Current function value: 0.199410
#          Iterations 15
# (1944.9736646318647, '-', 'X43')
# Optimization terminated successfully.
#          Current function value: 0.198335
#          Iterations 15
# (1935.0747830943976, '-', 'X3')
# Optimization terminated successfully.
#          Current function value: 0.199235
#          Iterations 15
# (1943.3574426489995, '-', 'X7')
# Optimization terminated successfully.
#          Current function value: 0.199549
#          Iterations 16
# (1946.2514440886134, '-', 'X56')
# Optimization terminated successfully.
#          Current function value: 0.223839
#          Iterations 15
# (2169.7694954662406, '-', 'X26')
# Optimization terminated successfully.
#          Current function value: 0.197908
#          Iterations 15
# (1931.1471908079288, '-', 'X18')
# Optimization terminated successfully.
#          Current function value: 0.198538
#          Iterations 15
# (1936.950442466048, '-', 'X32')
# Optimization terminated successfully.
#          Current function value: 0.199252
#          Iterations 15
# (1943.5130456896718, '-', 'X48')
# Optimization terminated successfully.
#          Current function value: 0.199838
#          Iterations 16
# (1948.9118383896503, '-', 'X16')
# Optimization terminated successfully.
#          Current function value: 0.198239
#          Iterations 15
# (1934.1977698459425, '-', 'X1')
# Optimization terminated successfully.
#          Current function value: 0.197559
#          Iterations 15
# (1927.9420019877173, '-', 'X21')
# Optimization terminated successfully.
#          Current function value: 0.197476
#          Iterations 15
# (1927.1735500157652, '-', 'X29')
# Optimization terminated successfully.
#          Current function value: 0.198876
#          Iterations 15
# (1940.0606620630017, '-', 'X55')
# Optimization terminated successfully.
#          Current function value: 0.210663
#          Iterations 16
# (2048.52291577571, '-', 'X24')
# Optimization terminated successfully.
#          Current function value: 0.201548
#          Iterations 15
# (1964.6426784521996, '-', 'X4')
# Optimization terminated successfully.
#          Current function value: 0.200113
#          Iterations 14
# (1951.4374425393091, '-', 'X40')
# Optimization terminated successfully.
#          Current function value: 0.201842
#          Iterations 15
# (1967.3524269051227, '-', 'X22')
# Optimization terminated successfully.
#          Current function value: 0.197726
#          Iterations 15
# (1929.4756412220652, '-', 'X14')
# Optimization terminated successfully.
#          Current function value: 0.198468
#          Iterations 15
# (1936.3052905438149, '-', 'X28')
# Optimization terminated successfully.
#          Current function value: 0.197459
#          Iterations 15
# (1927.0180081438746, '-', 'X13')
# Optimization terminated successfully.
#          Current function value: 0.199027
#          Iterations 15
# (1941.4453287675271, '-', 'X5')
# Optimization terminated successfully.
#          Current function value: 0.197452
#          Iterations 15
# (1926.9508387640972, '-', 'X50')
# Optimization terminated successfully.
#          Current function value: 0.198059
#          Iterations 15
# (1932.5357117362119, '-', 'X53')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.209205
#          Iterations: 35
# (2035.108050101436, '-', 'X15')
# Optimization terminated successfully.
#          Current function value: 0.198153
#          Iterations 15
# (1933.4023821323872, '-', 'X38')
# Optimization terminated successfully.
#          Current function value: 0.197423
#          Iterations 15
# (1926.6865412384907, '-', 'X10')
# Optimization terminated successfully.
#          Current function value: 0.197458
#          Iterations 15
# (1927.0073251122758, '-', 'X17')
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Optimization terminated successfully.
#          Current function value: 0.197372
#          Iterations 15
# (1926.2137629946117, '-', 'X30')
# Optimization terminated successfully.
#          Current function value: 0.199177
#          Iterations 15
# (1942.8282517113585, '-', 'X47')
# Optimization terminated successfully.
#          Current function value: 0.198669
#          Iterations 15
# (1938.1558547983286, '-', 'X19')
# Optimization terminated successfully.
#          Current function value: 0.202997
#          Iterations 15
# (1977.9765258328678, '-', 'X41')
# Optimization terminated successfully.
#          Current function value: 0.198224
#          Iterations 15
# (1934.0538060396593, '-', 'X25')
# Optimization terminated successfully.
#          Current function value: 0.197455
#          Iterations 15
# (1926.9834863111473, '-', 'X2')
# Optimization terminated successfully.
#          Current function value: 0.197708
#          Iterations 15
# (1929.3108737676666, '-', 'X9')
# Optimization terminated successfully.
#          Current function value: 0.197417
#          Iterations 15
# (1926.6284999605336, '-', 'X31')
# Optimization terminated successfully.
#          Current function value: 0.197754
#          Iterations 15
# (1929.7337104389537, '-', 'X11')
# Optimization terminated successfully.
#          Current function value: 0.197365
#          Iterations 15
# (1926.155187243349, '-', 'X33')
# Optimization terminated successfully.
#          Current function value: 0.197842
#          Iterations 15
# (1930.5466670684918, '-', 'X42')
# Optimization terminated successfully.
#          Current function value: 0.207230
#          Iterations 15
# (2016.9307799920934, '-', 'X52')
# Optimization terminated successfully.
#          Current function value: 0.198117
#          Iterations 15
# (1933.0716703479252, '-', 'X8')
# Optimization terminated successfully.
#          Current function value: 0.198277
#          Iterations 15
# (1934.5493989045485, '-', 'X34')
# Optimization terminated successfully.
#          Current function value: 0.202584
#          Iterations 16
# (1974.1749444091183, '-', 'X44')
# Optimization terminated successfully.
#          Current function value: 0.197407
#          Iterations 15
# (1926.5388770341028, '-', 'X49')
# Optimization terminated successfully.
#          Current function value: 0.198654
#          Iterations 15
# (1938.0111365633438, '-', 'X23')
# Optimization terminated successfully.
#          Current function value: 0.208302
#          Iterations 15
# (2026.798236199859, '-', 'X6')
# Optimization terminated successfully.
#          Current function value: 0.199761
#          Iterations 15
# (1948.204810188975, '-', 'X20')
# Optimization terminated successfully.
#          Current function value: 0.197736
#          Iterations 15
# (1929.567278500754, '-', 'X37')
# Optimization terminated successfully.
#          Current function value: 0.197392
#          Iterations 15
# (1926.400077636284, '-', 'X54')
# ----------------------------------------------
# (1926.155187243349, 'New Current', {'X35', 'X51', 'X45', 'X46', 'X27', 'X39', 'X0', 'X43', 'X3', 'X7', 'X56', 'X26', 'X18', 'X32', 'X48', 'X16', 'X1', 'X21', 'X29', 'X55', 'X24', 'X4', 'X40', 'X22', 'X14', 'X28', 'X13', 'X5', 'X50', 'X53', 'X15', 'X38', 'X10', 'X17', 'X30', 'X47', 'X19', 'X41', 'X25', 'X2', 'X9', 'X31', 'X11', 'X42', 'X52', 'X8', 'X34', 'X44', 'X49', 'X23', 'X6', 'X20', 'X37', 'X54'})
# Optimization terminated successfully.
#          Current function value: 0.198305
#          Iterations 15
# (1932.798485136882, '-', 'X35')
# Optimization terminated successfully.
#          Current function value: 0.200677
#          Iterations 15
# (1954.629849198766, '-', 'X51')
# Optimization terminated successfully.
#          Current function value: 0.204806
#          Iterations 15
# (1992.62654153914, '-', 'X45')
# Optimization terminated successfully.
#          Current function value: 0.197877
#          Iterations 15
# (1928.863561522683, '-', 'X46')
# Optimization terminated successfully.
#          Current function value: 0.198160
#          Iterations 15
# (1931.4685453352413, '-', 'X27')
# Optimization terminated successfully.
#          Current function value: 0.197452
#          Iterations 15
# (1924.9494076607953, '-', 'X39')
# Optimization terminated successfully.
#          Current function value: 0.197697
#          Iterations 15
# (1927.211968416096, '-', 'X0')
# Optimization terminated successfully.
#          Current function value: 0.199431
#          Iterations 15
# (1943.167235234319, '-', 'X43')
# Optimization terminated successfully.
#          Current function value: 0.198354
#          Iterations 15
# (1933.2490292564573, '-', 'X3')
# Optimization terminated successfully.
#          Current function value: 0.199256
#          Iterations 15
# (1941.5547963332745, '-', 'X7')
# Optimization terminated successfully.
#          Current function value: 0.199575
#          Iterations 16
# (1944.4916107877898, '-', 'X56')
# Optimization terminated successfully.
#          Current function value: 0.223898
#          Iterations 15
# (2168.3062805814175, '-', 'X26')
# Optimization terminated successfully.
#          Current function value: 0.197925
#          Iterations 15
# (1929.3017669097103, '-', 'X18')
# Optimization terminated successfully.
#          Current function value: 0.198560
#          Iterations 15
# (1935.1527340133741, '-', 'X32')
# Optimization terminated successfully.
#          Current function value: 0.199273
#          Iterations 15
# (1941.7105605201289, '-', 'X48')
# Optimization terminated successfully.
#          Current function value: 0.199855
#          Iterations 16
# (1947.0639681556036, '-', 'X16')
# Optimization terminated successfully.
#          Current function value: 0.198262
#          Iterations 15
# (1932.4026197901562, '-', 'X1')
# Optimization terminated successfully.
#          Current function value: 0.197580
#          Iterations 15
# (1926.133611068415, '-', 'X21')
# Optimization terminated successfully.
#          Current function value: 0.197497
#          Iterations 15
# (1925.3649726467743, '-', 'X29')
# Optimization terminated successfully.
#          Current function value: 0.198904
#          Iterations 15
# (1938.3180168331198, '-', 'X55')
# Optimization terminated successfully.
#          Current function value: 0.210679
#          Iterations 16
# (2046.6683336283309, '-', 'X24')
# Optimization terminated successfully.
#          Current function value: 0.201563
#          Iterations 15
# (1962.78713873051, '-', 'X4')
# Optimization terminated successfully.
#          Current function value: 0.200134
#          Iterations 14
# (1949.6356983810865, '-', 'X40')
# Optimization terminated successfully.
#          Current function value: 0.201858
#          Iterations 15
# (1965.4983169529014, '-', 'X22')
# Optimization terminated successfully.
#          Current function value: 0.197746
#          Iterations 15
# (1927.661743324017, '-', 'X14')
# Optimization terminated successfully.
#          Current function value: 0.198490
#          Iterations 15
# (1934.5066435761707, '-', 'X28')
# Optimization terminated successfully.
#          Current function value: 0.197480
#          Iterations 15
# (1925.20846252455, '-', 'X13')
# Optimization terminated successfully.
#          Current function value: 0.199044
#          Iterations 15
# (1939.5986663722065, '-', 'X5')
# Optimization terminated successfully.
#          Current function value: 0.197473
#          Iterations 15
# (1925.1449205641356, '-', 'X50')
# Optimization terminated successfully.
#          Current function value: 0.198079
#          Iterations 15
# (1930.7226287018989, '-', 'X53')
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.211629
#          Iterations: 35
# c:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# (2055.4113068935194, '-', 'X15')
# Optimization terminated successfully.
#          Current function value: 0.198173
#          Iterations 15
# (1931.5919496495967, '-', 'X38')
# Optimization terminated successfully.
#          Current function value: 0.197447
#          Iterations 15
# (1924.9050827199471, '-', 'X10')
# Optimization terminated successfully.
#          Current function value: 0.197478
#          Iterations 15
# (1925.1926568308036, '-', 'X17')
# Optimization terminated successfully.
#          Current function value: 0.197392
#          Iterations 15
# (1924.4056155735882, '-', 'X30')
# Optimization terminated successfully.
#          Current function value: 0.199198
#          Iterations 15
# (1941.0223030259217, '-', 'X47')
# Optimization terminated successfully.
#          Current function value: 0.198688
#          Iterations 15
# (1936.3307390470716, '-', 'X19')
# Optimization terminated successfully.
#          Current function value: 0.203020
#          Iterations 15
# (1976.1920282448173, '-', 'X41')
# Optimization terminated successfully.
#          Current function value: 0.198244
#          Iterations 15
# (1932.2372534148203, '-', 'X25')
# Optimization terminated successfully.
#          Current function value: 0.197478
#          Iterations 15
# (1925.1880259580112, '-', 'X2')
# Optimization terminated successfully.
#          Current function value: 0.197733
#          Iterations 15
# (1927.5402552381083, '-', 'X9')
# Optimization terminated successfully.
#          Current function value: 0.197438
#          Iterations 15
# (1924.8270199273613, '-', 'X31')
# Optimization terminated successfully.
#          Current function value: 0.197780
#          Iterations 15
# (1927.9685081140087, '-', 'X11')
# Optimization terminated successfully.
#          Current function value: 0.197864
#          Iterations 15
# (1928.740907198107, '-', 'X42')
# Optimization terminated successfully.
#          Current function value: 0.207294
#          Iterations 15
# (2015.519518356, '-', 'X52')
# Optimization terminated successfully.
#          Current function value: 0.198134
#          Iterations 15
# (1931.229709640012, '-', 'X8')
# Optimization terminated successfully.
#          Current function value: 0.198300
#          Iterations 15
# (1932.755446775619, '-', 'X34')
# Optimization terminated successfully.
#          Current function value: 0.202616
#          Iterations 16
# (1972.473780809326, '-', 'X44')
# Optimization terminated successfully.
#          Current function value: 0.197428
#          Iterations 15
# (1924.7369221130684, '-', 'X49')
# Optimization terminated successfully.
#          Current function value: 0.198673
#          Iterations 15
# (1936.1907315163662, '-', 'X23')
# Optimization terminated successfully.
#          Current function value: 0.208318
#          Iterations 15
# (2024.945010171726, '-', 'X6')
# Optimization terminated successfully.
#          Current function value: 0.199789
#          Iterations 15
# (1946.4544263412492, '-', 'X20')
# Optimization terminated successfully.
#          Current function value: 0.197756
#          Iterations 15
# (1927.754292563991, '-', 'X37')
# Optimization terminated successfully.
#          Current function value: 0.197411
#          Iterations 15
# (1924.5770736048044, '-', 'X54')
# ----------------------------------------------
# (1924.4056155735882, 'New Current', {'X35', 'X51', 'X45', 'X46', 'X27', 'X39', 'X0', 'X43', 'X3', 'X7', 'X56', 'X26', 'X18', 'X32', 'X48', 'X16', 'X1', 'X21', 'X29', 'X55', 'X24', 'X4', 'X40', 'X22', 'X14', 'X28', 'X13', 'X5', 'X50', 'X53', 'X15', 'X38', 'X10', 'X17', 'X47', 'X19', 'X41', 'X25', 'X2', 'X9', 'X31', 'X11', 'X42', 'X52', 'X8', 'X34', 'X44', 'X49', 'X23', 'X6', 'X20', 'X37', 'X54'})
# Optimization terminated successfully.
#          Current function value: 0.198336
#          Iterations 15
# (1931.0872430696822, '-', 'X35')
# Optimization terminated successfully.
#          Current function value: 0.200710
#          Iterations 15
# (1952.929496506326, '-', 'X51')
# Optimization terminated successfully.
#          Current function value: 0.204822
#          Iterations 15
# (1990.7712694003221, '-', 'X45')
# Optimization terminated successfully.
#          Current function value: 0.197904
#          Iterations 15
# (1927.112759476257, '-', 'X46')
# Optimization terminated successfully.
#          Current function value: 0.198187
#          Iterations 15
# (1929.7179669717389, '-', 'X27')
# Optimization terminated successfully.
#          Current function value: 0.197479
#          Iterations 15
# (1923.1987951547146, '-', 'X39')
# Optimization terminated successfully.
#          Current function value: 0.197724
#          Iterations 15
# (1925.4600710375385, '-', 'X0')
# Optimization terminated successfully.
#          Current function value: 0.199696
#          Iterations 15
# (1943.6033989512034, '-', 'X43')
# Optimization terminated successfully.
#          Current function value: 0.198383
#          Iterations 15
# (1931.5186190978643, '-', 'X3')
# Optimization terminated successfully.
#          Current function value: 0.199285
#          Iterations 15
# (1939.820945999806, '-', 'X7')
# Optimization terminated successfully.
#          Current function value: 0.199610
#          Iterations 16
# (1942.8105132362884, '-', 'X56')
# Optimization terminated successfully.
#          Current function value: 0.224315
#          Iterations 15
# (2170.149748557885, '-', 'X26')
# Optimization terminated successfully.
#          Current function value: 0.197956
#          Iterations 15
# (1927.5865953563516, '-', 'X18')
# Optimization terminated successfully.
#          Current function value: 0.198587
#          Iterations 15
# (1933.3962926235004, '-', 'X32')
# Optimization terminated successfully.
#          Current function value: 0.199298
#          Iterations 15
# (1939.938567701946, '-', 'X48')
# Optimization terminated successfully.
#          Current function value: 0.199888
#          Iterations 16
# (1945.373266130804, '-', 'X16')
# Optimization terminated successfully.
#          Current function value: 0.198285
#          Iterations 15
# (1930.6209462393997, '-', 'X1')
# Optimization terminated successfully.
#          Current function value: 0.197607
#          Iterations 15
# (1924.3825508264363, '-', 'X21')
# Optimization terminated successfully.
#          Current function value: 0.197523
#          Iterations 15
# (1923.6101748744854, '-', 'X29')
# Optimization terminated successfully.
#          Current function value: 0.198927
#          Iterations 15
# (1936.524441489026, '-', 'X55')
# Optimization terminated successfully.
#          Current function value: 0.210955
#          Iterations 16
# (2047.210151363265, '-', 'X24')
# Optimization terminated successfully.
#          Current function value: 0.201600
#          Iterations 15
# (1961.1189031302345, '-', 'X4')
# Optimization terminated successfully.
#          Current function value: 0.200161
#          Iterations 14
# (1947.8836559236674, '-', 'X40')
# Optimization terminated successfully.
#          Current function value: 0.201889
#          Iterations 15
# (1963.7838138672334, '-', 'X22')
# Optimization terminated successfully.
#          Current function value: 0.197773
#          Iterations 15
# (1925.9092868397163, '-', 'X14')
# Optimization terminated successfully.
#          Current function value: 0.198516
#          Iterations 15
# (1932.7413880323984, '-', 'X28')
# Optimization terminated successfully.
#          Current function value: 0.197506
#          Iterations 15
# (1923.454735255414, '-', 'X13')
# Optimization terminated successfully.
#          Current function value: 0.199072
#          Iterations 15
# (1937.861219895056, '-', 'X5')
# Optimization terminated successfully.
#          Current function value: 0.197499
#          Iterations 15
# (1923.3892424576302, '-', 'X50')
# Optimization terminated successfully.
#          Current function value: 0.198106
#          Iterations 15
# (1928.9722948930385, '-', 'X53')
# Optimization terminated successfully.
#          Current function value: 0.207056
#          Iterations 15
# (2011.3259438986886, '-', 'X15')
# Optimization terminated successfully.
#          Current function value: 0.198200
#          Iterations 15
# (1929.8357680342965, '-', 'X38')
# Optimization terminated successfully.
#          Current function value: 0.197474
#          Iterations 15
# (1923.156500901715, '-', 'X10')
# Optimization terminated successfully.
#          Current function value: 0.197506
#          Iterations 15
# (1923.452242155942, '-', 'X17')
# Optimization terminated successfully.
#          Current function value: 0.199224
#          Iterations 15
# (1939.2633680994415, '-', 'X47')
# Optimization terminated successfully.
#          Current function value: 0.198717
#          Iterations 15
# (1934.5952777029524, '-', 'X19')
# Optimization terminated successfully.
#          Current function value: 0.203045
#          Iterations 15
# (1974.4164293210888, '-', 'X41')
# Optimization terminated successfully.
#          Current function value: 0.198265
#          Iterations 15
# (1930.4303487536856, '-', 'X25')
# Optimization terminated successfully.
#          Current function value: 0.197506
#          Iterations 15
# (1923.4512377194328, '-', 'X2')
# Optimization terminated successfully.
#          Current function value: 0.197760
#          Iterations 15
# (1925.7909079147635, '-', 'X9')
# Optimization terminated successfully.
#          Current function value: 0.197466
#          Iterations 15
# (1923.0777008298003, '-', 'X31')
# Optimization terminated successfully.
#          Current function value: 0.197803
#          Iterations 15
# (1926.1856375719015, '-', 'X11')
# Optimization terminated successfully.
#          Current function value: 0.197890
#          Iterations 15
# (1926.9875709298967, '-', 'X42')
# Optimization terminated successfully.
#          Current function value: 0.207333
#          Iterations 15
# (2013.8788536863606, '-', 'X52')
# Optimization terminated successfully.
#          Current function value: 0.198165
#          Iterations 15
# (1929.517409845464, '-', 'X8')
# Optimization terminated successfully.
#          Current function value: 0.198352
#          Iterations 15
# (1931.2354276781703, '-', 'X34')
# Optimization terminated successfully.
#          Current function value: 0.202636
#          Iterations 16
# (1970.658742893271, '-', 'X44')
# Optimization terminated successfully.
#          Current function value: 0.197455
#          Iterations 15
# (1922.977257981128, '-', 'X49')
# Optimization terminated successfully.
#          Current function value: 0.198701
#          Iterations 15
# (1934.448271094685, '-', 'X23')
# Optimization terminated successfully.
#          Current function value: 0.208353
#          Iterations 15
# (2023.260035228746, '-', 'X6')
# Optimization terminated successfully.
#          Current function value: 0.199817
#          Iterations 15
# (1944.720414048599, '-', 'X20')
# Optimization terminated successfully.
#          Current function value: 0.197783
#          Iterations 15
# (1925.996566023958, '-', 'X37')
# Optimization terminated successfully.
#          Current function value: 0.197440
#          Iterations 15
# (1922.846172866969, '-', 'X54')
# ----------------------------------------------
# (1922.846172866969, 'New Current', {'X35', 'X51', 'X45', 'X46', 'X27', 'X39', 'X0', 'X43', 'X3', 'X7', 'X56', 'X26', 'X18', 'X32', 'X48', 'X16', 'X1', 'X21', 'X29', 'X55', 'X24', 'X4', 'X40', 'X22', 'X14', 'X28', 'X13', 'X5', 'X50', 'X53', 'X15', 'X38', 'X10', 'X17', 'X47', 'X19', 'X41', 'X25', 'X2', 'X9', 'X31', 'X11', 'X42', 'X52', 'X8', 'X34', 'X44', 'X49', 'X23', 'X6', 'X20', 'X37'})
# Optimization terminated successfully.
#          Current function value: 0.198392
#          Iterations 15
# (1929.59924889752, '-', 'X35')
# Optimization terminated successfully.
#          Current function value: 0.200791
#          Iterations 15
# (1951.6809376706433, '-', 'X51')
# Optimization terminated successfully.
#          Current function value: 0.204906
#          Iterations 15
# (1989.5428618859978, '-', 'X45')
# Optimization terminated successfully.
#          Current function value: 0.197945
#          Iterations 15
# (1925.4920976127391, '-', 'X46')
# Optimization terminated successfully.
#          Current function value: 0.198237
#          Iterations 15
# (1928.1786232756967, '-', 'X27')
# Optimization terminated successfully.
#          Current function value: 0.197527
#          Iterations 15
# (1921.6430433327869, '-', 'X39')
# Optimization terminated successfully.
#          Current function value: 0.197760
#          Iterations 15
# (1923.7898527126972, '-', 'X0')
# Optimization terminated successfully.
#          Current function value: 0.199739
#          Iterations 15
# (1941.9992722031652, '-', 'X43')
# Optimization terminated successfully.
#          Current function value: 0.198424
#          Iterations 15
# (1929.9018131917005, '-', 'X3')
# Optimization terminated successfully.
#          Current function value: 0.199342
#          Iterations 15
# (1938.3435898832902, '-', 'X7')
# Optimization terminated successfully.
#          Current function value: 0.199624
#          Iterations 16
# (1940.9356332695384, '-', 'X56')
# Optimization terminated successfully.
#          Current function value: 0.224460
#          Iterations 15
# (2169.4839422778273, '-', 'X26')
# Optimization terminated successfully.
#          Current function value: 0.198003
#          Iterations 15
# (1926.0260373860447, '-', 'X18')
# Optimization terminated successfully.
#          Current function value: 0.198651
#          Iterations 15
# (1931.9848507891054, '-', 'X32')
# Optimization terminated successfully.
#          Current function value: 0.199354
#          Iterations 15
# (1938.4549922408391, '-', 'X48')
# Optimization terminated successfully.
#          Current function value: 0.199909
#          Iterations 16
# (1943.5599024125704, '-', 'X16')
# Optimization terminated successfully.
#          Current function value: 0.198345
#          Iterations 15
# (1929.1737338535067, '-', 'X1')
# Optimization terminated successfully.
#          Current function value: 0.197666
#          Iterations 15
# (1922.918875245852, '-', 'X21')
# Optimization terminated successfully.
#          Current function value: 0.197567
#          Iterations 15
# (1922.014626531882, '-', 'X29')
# Optimization terminated successfully.
#          Current function value: 0.201389
#          Iterations 15
# (1957.1826475790297, '-', 'X55')
# Optimization terminated successfully.
#          Current function value: 0.211021
#          Iterations 16
# (2045.8143048237666, '-', 'X24')
# Optimization terminated successfully.
#          Current function value: 0.201641
#          Iterations 15
# (1959.4960536938406, '-', 'X4')
# Optimization terminated successfully.
#          Current function value: 0.200177
#          Iterations 14
# (1946.0298528116118, '-', 'X40')
# Optimization terminated successfully.
#          Current function value: 0.201932
#          Iterations 15
# (1962.1815210034147, '-', 'X22')
# Optimization terminated successfully.
#          Current function value: 0.197816
#          Iterations 15
# (1924.2993041955367, '-', 'X14')
# Optimization terminated successfully.
#          Current function value: 0.198559
#          Iterations 15
# (1931.138723895935, '-', 'X28')
# Optimization terminated successfully.
#          Current function value: 0.197547
#          Iterations 15
# (1921.8251124224842, '-', 'X13')
# Optimization terminated successfully.
#          Current function value: 0.199087
#          Iterations 15
# (1935.9973570622883, '-', 'X5')
# Optimization terminated successfully.
#          Current function value: 0.197545
#          Iterations 15
# (1921.8089668928371, '-', 'X50')
# Optimization terminated successfully.
#          Current function value: 0.198167
#          Iterations 15
# (1927.537201192923, '-', 'X53')
# Optimization terminated successfully.
#          Current function value: 0.207180
#          Iterations 15
# (2010.4671823365593, '-', 'X15')
# Optimization terminated successfully.
#          Current function value: 0.198249
#          Iterations 15
# (1928.2887341054711, '-', 'X38')
# Optimization terminated successfully.
#          Current function value: 0.197525
#          Iterations 15
# (1921.625536980503, '-', 'X10')
# Optimization terminated successfully.
#          Current function value: 0.197544
#          Iterations 15
# (1921.7975009590402, '-', 'X17')
# Optimization terminated successfully.
#          Current function value: 0.199269
#          Iterations 15
# (1937.6737528679068, '-', 'X47')
# Optimization terminated successfully.
#          Current function value: 0.198743
#          Iterations 15
# (1932.8307450082502, '-', 'X19')
# Optimization terminated successfully.
#          Current function value: 0.203199
#          Iterations 15
# (1973.8368653794857, '-', 'X41')
# Optimization terminated successfully.
#          Current function value: 0.198309
#          Iterations 15
# (1928.843214856944, '-', 'X25')
# Optimization terminated successfully.
#          Current function value: 0.197548
#          Iterations 15
# (1921.8387386509107, '-', 'X2')
# Optimization terminated successfully.
#          Current function value: 0.197823
#          Iterations 15
# (1924.369335507445, '-', 'X9')
# Optimization terminated successfully.
#          Current function value: 0.197514
#          Iterations 15
# (1921.5271676999314, '-', 'X31')
# Optimization terminated successfully.
#          Current function value: 0.197864
#          Iterations 15
# (1924.744509661758, '-', 'X11')
# Optimization terminated successfully.
#          Current function value: 0.197941
#          Iterations 15
# (1925.4541932348448, '-', 'X42')
# Optimization terminated successfully.
#          Current function value: 0.207355
#          Iterations 15
# (2012.0795474725037, '-', 'X52')
# Optimization terminated successfully.
#          Current function value: 0.198176
#          Iterations 15
# (1927.619918973919, '-', 'X8')
# Optimization terminated successfully.
#          Current function value: 0.198452
#          Iterations 15
# (1930.1510962792036, '-', 'X34')
# Optimization terminated successfully.
#          Current function value: 0.202700
#          Iterations 16
# (1969.2457410688166, '-', 'X44')
# Optimization terminated successfully.
#          Current function value: 0.197500
#          Iterations 15
# (1921.3991742674934, '-', 'X49')
# Optimization terminated successfully.
#          Current function value: 0.198760
#          Iterations 15
# (1932.9922112543802, '-', 'X23')
# Optimization terminated successfully.
#          Current function value: 0.208479
#          Iterations 15
# (2022.4283212126397, '-', 'X6')
# Optimization terminated successfully.
#          Current function value: 0.199875
#          Iterations 15
# (1943.2465347169032, '-', 'X20')
# ...
#          Current function value: 0.198513
#          Iterations 15
# (1916.7134758669308, '-', 'X14')
# Optimization terminated successfully.
#          Current function value: 0.199130
#          Iterations 15
# (1922.3982790397072, '-', 'X28')
# Optimization terminated successfully.
#          Current function value: 0.199633
#          Iterations 15
# (1927.0248630104834, '-', 'X5')
# Optimization terminated successfully.
#          Current function value: 0.198698
#          Iterations 15
# (1918.4224437700905, '-', 'X53')
# Optimization terminated successfully.
#          Current function value: 0.207949
#          Iterations 15
# (2003.5479978612595, '-', 'X15')
# Optimization terminated successfully.
#          Current function value: 0.198878
#          Iterations 15
# (1920.074566989058, '-', 'X38')
# Optimization terminated successfully.
#          Current function value: 0.199924
#          Iterations 15
# (1929.6999749389681, '-', 'X47')
# Optimization terminated successfully.
#          Current function value: 0.199385
#          Iterations 15
# (1924.742241910211, '-', 'X19')
# Optimization terminated successfully.
#          Current function value: 0.203736
#          Iterations 15
# (1964.7818213789114, '-', 'X41')
# Optimization terminated successfully.
#          Current function value: 0.198921
#          Iterations 15
# (1920.4672951521115, '-', 'X25')
# Optimization terminated successfully.
#          Current function value: 0.198182
#          Iterations 15
# (1913.6683332052448, '-', 'X2')
# Optimization terminated successfully.
#          Current function value: 0.198394
#          Iterations 15
# (1915.6248296694087, '-', 'X9')
# Optimization terminated successfully.
#          Current function value: 0.198480
#          Iterations 15
# (1916.4138411807867, '-', 'X11')
# Optimization terminated successfully.
#          Current function value: 0.198552
#          Iterations 15
# (1917.0745323903539, '-', 'X42')
# Optimization terminated successfully.
#          Current function value: 0.208427
#          Iterations 15
# (2007.9434559608067, '-', 'X52')
# Optimization terminated successfully.
#          Current function value: 0.198733
#          Iterations 15
# (1918.738166613744, '-', 'X8')
# Optimization terminated successfully.
#          Current function value: 0.199060
#          Iterations 15
# (1921.750598198938, '-', 'X34')
# Optimization terminated successfully.
#          Current function value: 0.203445
#          Iterations 15
# (1962.103807097492, '-', 'X44')
# Optimization terminated successfully.
#          Current function value: 0.199392
#          Iterations 15
# (1924.8006880586822, '-', 'X23')
# Optimization terminated successfully.
#          Current function value: 0.209261
#          Iterations 15
# (2015.6172696429294, '-', 'X6')
# Optimization terminated successfully.
#          Current function value: 0.200467
#          Iterations 15
# (1934.6949016918213, '-', 'X20')
# Optimization terminated successfully.
#          Current function value: 0.198447
#          Iterations 15
# (1916.1088078181406, '-', 'X37')
# ----------------------------------------------
# (1913.6683332052448, 'New Current', {'X35', 'X51', 'X45', 'X46', 'X27', 'X0', 'X43', 'X3', 'X7', 'X56', 'X26', 'X18', 'X32', 'X48', 'X16', 'X1', 'X21', 'X29', 'X55', 'X24', 'X4', 'X40', 'X22', 'X14', 'X28', 'X5', 'X53', 'X15', 'X38', 'X47', 'X19', 'X41', 'X25', 'X9', 'X11', 'X42', 'X52', 'X8', 'X34', 'X44', 'X23', 'X6', 'X20', 'X37'})
# Optimization terminated successfully.
#          Current function value: 0.199197
#          Iterations 15
# (1921.0084660440934, '-', 'X35')
# Optimization terminated successfully.
#          Current function value: 0.201546
#          Iterations 15
# (1942.6271744991484, '-', 'X51')
# Optimization terminated successfully.
#          Current function value: 0.205795
#          Iterations 15
# (1981.729534408481, '-', 'X45')
# Optimization terminated successfully.
#          Current function value: 0.198629
#          Iterations 15
# (1915.7847831822614, '-', 'X46')
# Optimization terminated successfully.
#          Current function value: 0.198912
#          Iterations 15
# (1918.3920540573172, '-', 'X27')
# Optimization terminated successfully.
#          Current function value: 0.198752
#          Iterations 15
# (1916.9202159869874, '-', 'X0')
# Optimization terminated successfully.
#          Current function value: 0.200505
#          Iterations 15
# (1933.0477571780907, '-', 'X43')
# Optimization terminated successfully.
#          Current function value: 0.199159
#          Iterations 15
# (1920.6643662797976, '-', 'X3')
# Optimization terminated successfully.
#          Current function value: 0.200055
#          Iterations 15
# (1928.906684918859, '-', 'X7')
# Optimization terminated successfully.
#          Current function value: 0.200324
#          Iterations 16
# (1931.3821450199111, '-', 'X56')
# Optimization terminated successfully.
#          Current function value: 0.227386
#          Iterations 15
# (2180.4074834659914, '-', 'X26')
# Optimization terminated successfully.
#          Current function value: 0.198910
#          Iterations 15
# (1918.3726124268142, '-', 'X18')
# Optimization terminated successfully.
#          Current function value: 0.199449
#          Iterations 15
# (1923.32992589612, '-', 'X32')
# Optimization terminated successfully.
#          Current function value: 0.200134
#          Iterations 15
# (1929.631076321825, '-', 'X48')
# Optimization terminated successfully.
#          Current function value: 0.200709
#          Iterations 15
# (1934.9264841607255, '-', 'X16')
# Optimization terminated successfully.
#          Current function value: 0.199043
#          Iterations 15
# (1919.5923409891193, '-', 'X1')
# Optimization terminated successfully.
#          Current function value: 0.198442
#          Iterations 15
# (1914.065063562416, '-', 'X21')
# Optimization terminated successfully.
#          Current function value: 0.198313
#          Iterations 15
# (1912.875893729102, '-', 'X29')
# Optimization terminated successfully.
#          Current function value: 0.202421
#          Iterations 15
# (1950.676901108537, '-', 'X55')
# Optimization terminated successfully.
#          Current function value: 0.212104
#          Iterations 16
# (2039.7787268537413, '-', 'X24')
# Optimization terminated successfully.
#          Current function value: 0.202455
#          Iterations 15
# (1950.9871865825394, '-', 'X4')
# Optimization terminated successfully.
#          Current function value: 0.200879
#          Iterations 13
# (1936.4853551048177, '-', 'X40')
# Optimization terminated successfully.
#          Current function value: 0.202499
#          Iterations 15
# (1951.3954460120171, '-', 'X22')
# Optimization terminated successfully.
#          Current function value: 0.198666
#          Iterations 15
# (1916.1231266868178, '-', 'X14')
# Optimization terminated successfully.
#          Current function value: 0.199223
#          Iterations 15
# (1921.2468024854657, '-', 'X28')
# Optimization terminated successfully.
#          Current function value: 0.199745
#          Iterations 15
# (1926.0528615535968, '-', 'X5')
# Optimization terminated successfully.
#          Current function value: 0.198829
#          Iterations 15
# (1917.6229099780435, '-', 'X53')
# Optimization terminated successfully.
#          Current function value: 0.208148
#          Iterations 15
# (2003.376568331477, '-', 'X15')
# Optimization terminated successfully.
#          Current function value: 0.198994
#          Iterations 15
# (1919.1398516031163, '-', 'X38')
# Optimization terminated successfully.
#          Current function value: 0.200075
#          Iterations 15
# (1929.0917598313756, '-', 'X47')
# Optimization terminated successfully.
#          Current function value: 0.199513
#          Iterations 15
# (1923.9173934746175, '-', 'X19')
# Optimization terminated successfully.
#          Current function value: 0.203850
#          Iterations 15
# (1963.8233465564258, '-', 'X41')
# Optimization terminated successfully.
#          Current function value: 0.199047
#          Iterations 15
# (1919.6321940755543, '-', 'X25')
# Optimization terminated successfully.
#          Current function value: 0.198513
#          Iterations 15
# (1914.7183477384492, '-', 'X9')
# Optimization terminated successfully.
#          Current function value: 0.198596
#          Iterations 15
# (1915.4786562243905, '-', 'X11')
# Optimization terminated successfully.
#          Current function value: 0.198687
#          Iterations 15
# (1916.3162035940077, '-', 'X42')
# Optimization terminated successfully.
#          Current function value: 0.208565
#          Iterations 15
# (2007.2138480145732, '-', 'X52')
# Optimization terminated successfully.
#          Current function value: 0.198884
#          Iterations 15
# (1918.1295822281736, '-', 'X8')
# Optimization terminated successfully.
#          Current function value: 0.199206
#          Iterations 15
# (1921.0934553877423, '-', 'X34')
# Optimization terminated successfully.
#          Current function value: 0.203648
#          Iterations 15
# (1961.9734884004047, '-', 'X44')
# Optimization terminated successfully.
#          Current function value: 0.199521
#          Iterations 15
# (1923.9952659568319, '-', 'X23')
# Optimization terminated successfully.
#          Current function value: 0.209317
#          Iterations 15
# (2014.1372149152394, '-', 'X6')
# Optimization terminated successfully.
#          Current function value: 0.200642
#          Iterations 15
# (1934.3112944762322, '-', 'X20')
# Optimization terminated successfully.
#          Current function value: 0.198585
#          Iterations 15
# (1915.3778499197724, '-', 'X37')
# ----------------------------------------------
# (1912.875893729102, 'New Current', {'X35', 'X51', 'X45', 'X46', 'X27', 'X0', 'X43', 'X3', 'X7', 'X56', 'X26', 'X18', 'X32', 'X48', 'X16', 'X1', 'X21', 'X55', 'X24', 'X4', 'X40', 'X22', 'X14', 'X28', 'X5', 'X53', 'X15', 'X38', 'X47', 'X19', 'X41', 'X25', 'X9', 'X11', 'X42', 'X52', 'X8', 'X34', 'X44', 'X23', 'X6', 'X20', 'X37'})
# Optimization terminated successfully.
#          Current function value: 0.199338
#          Iterations 15
# (1920.3096086252476, '-', 'X35')
# Optimization terminated successfully.
#          Current function value: 0.201712
#          Iterations 15
# (1942.1562446230998, '-', 'X51')
# Optimization terminated successfully.
#          Current function value: 0.205902
#          Iterations 15
# (1980.707266297774, '-', 'X45')
# Optimization terminated successfully.
#          Current function value: 0.198761
#          Iterations 15
# (1914.9965439222237, '-', 'X46')
# Optimization terminated successfully.
#          Current function value: 0.199041
#          Iterations 15
# (1917.5727691316247, '-', 'X27')
# Optimization terminated successfully.
#          Current function value: 0.198876
#          Iterations 15
# (1916.0600042021904, '-', 'X0')
# Optimization terminated successfully.
#          Current function value: 0.200662
#          Iterations 15
# (1932.4961412321973, '-', 'X43')
# Optimization terminated successfully.
#          Current function value: 0.199293
#          Iterations 15
# (1919.8929214259615, '-', 'X3')
# Optimization terminated successfully.
#          Current function value: 0.200188
#          Iterations 15
# (1928.1345075700178, '-', 'X7')
# Optimization terminated successfully.
#          Current function value: 0.200513
#          Iterations 16
# (1931.1191106601564, '-', 'X56')
# Optimization terminated successfully.
#          Current function value: 0.227424
#          Iterations 15
# (2178.7586302084237, '-', 'X26')
# Optimization terminated successfully.
#          Current function value: 0.199038
#          Iterations 15
# (1917.5471457281028, '-', 'X18')
# Optimization terminated successfully.
#          Current function value: 0.199567
#          Iterations 15
# (1922.4129637419662, '-', 'X32')
# Optimization terminated successfully.
#          Current function value: 0.200256
#          Iterations 15
# (1928.7578782291093, '-', 'X48')
# Optimization terminated successfully.
#          Current function value: 0.200825
#          Iterations 15
# (1933.99614853186, '-', 'X16')
# Optimization terminated successfully.
#          Current function value: 0.199164
#          Iterations 15
# (1918.7071175414794, '-', 'X1')
# Optimization terminated successfully.
#          Current function value: 0.198573
#          Iterations 15
# (1913.2646404520224, '-', 'X21')
# Optimization terminated successfully.
#          Current function value: 0.202524
#          Iterations 15
# (1949.6257528999554, '-', 'X55')
# Optimization terminated successfully.
#          Current function value: 0.213043
#          Iterations 16
# (2046.425138832092, '-', 'X24')
# Optimization terminated successfully.
#          Current function value: 0.202579
#          Iterations 15
# (1950.1301089975755, '-', 'X4')
# Optimization terminated successfully.
#          Current function value: 0.201070
#          Iterations 13
# (1936.2462988260568, '-', 'X40')
# Optimization terminated successfully.
#          Current function value: 0.202671
#          Iterations 15
# (1950.9813082186547, '-', 'X22')
# Optimization terminated successfully.
#          Current function value: 0.198783
#          Iterations 15
# (1915.1970242027226, '-', 'X14')
# Optimization terminated successfully.
#          Current function value: 0.199376
#          Iterations 15
# (1920.6554359377049, '-', 'X28')
# Optimization terminated successfully.
#          Current function value: 0.199848
#          Iterations 15
# (1924.9995108148228, '-', 'X5')
# Optimization terminated successfully.
#          Current function value: 0.198965
#          Iterations 15
# (1916.8742415579536, '-', 'X53')
# Optimization terminated successfully.
#          Current function value: 0.208287
#          Iterations 15
# (2002.6541645236362, '-', 'X15')
# Optimization terminated successfully.
#          Current function value: 0.199130
#          Iterations 15
# (1918.3912493917232, '-', 'X38')
# Optimization terminated successfully.
#          Current function value: 0.200208
#          Iterations 15
# (1928.311110557553, '-', 'X47')
# Optimization terminated successfully.
#          Current function value: 0.199665
#          Iterations 15
# (1923.3153328476712, '-', 'X19')
# Optimization terminated successfully.
#          Current function value: 0.203950
#          Iterations 15
# (1962.7507846618232, '-', 'X41')
# Optimization terminated successfully.
#          Current function value: 0.199202
#          Iterations 15
# (1919.0549573387193, '-', 'X25')
# Optimization terminated successfully.
#          Current function value: 0.198625
#          Iterations 15
# (1913.747760115588, '-', 'X9')
# Optimization terminated successfully.
#          Current function value: 0.198714
#          Iterations 15
# (1914.567943516902, '-', 'X11')
# Optimization terminated successfully.
#          Current function value: 0.198810
#          Iterations 15
# (1915.446397605485, '-', 'X42')
# Optimization terminated successfully.
#          Current function value: 0.208748
#          Iterations 15
# (2006.8979907079038, '-', 'X52')
# Optimization terminated successfully.
#          Current function value: 0.198988
#          Iterations 15
# (1917.0921719099997, '-', 'X8')
# Optimization terminated successfully.
#          Current function value: 0.199333
#          Iterations 15
# (1920.259559033959, '-', 'X34')
# Optimization terminated successfully.
#          Current function value: 0.203745
#          Iterations 15
# (1960.859171093357, '-', 'X44')
# Optimization terminated successfully.
#          Current function value: 0.199666
#          Iterations 15
# (1923.3242002095117, '-', 'X23')
# Optimization terminated successfully.
#          Current function value: 0.209501
#          Iterations 15
# (2013.8281486790559, '-', 'X6')
# Optimization terminated successfully.
#          Current function value: 0.200800
#          Iterations 15
# (1933.7639118102613, '-', 'X20')
# Optimization terminated successfully.
#          Current function value: 0.198714
#          Iterations 15
# (1914.5626388454161, '-', 'X37')
# ----------------------------------------------
# (1912.875893729102, 'Final', {'X35', 'X51', 'X45', 'X46', 'X27', 'X0', 'X43', 'X3', 'X7', 'X56', 'X26', 'X18', 'X32', 'X48', 'X16', 'X1', 'X21', 'X55', 'X24', 'X4', 'X40', 'X22', 'X14', 'X28', 'X5', 'X53', 'X15', 'X38', 'X47', 'X19', 'X41', 'X25', 'X9', 'X11', 'X42', 'X52', 'X8', 'X34', 'X44', 'X23', 'X6', 'X20', 'X37'})
# Optimization terminated successfully.
#          Current function value: 0.198313
#          Iterations 15

# %% [markdown]
# Le modèle sélectionné

# %%
print(modelefinal.summary())
# Out:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      Y   No. Observations:                 4601
# Model:                          Logit   Df Residuals:                     4557
# Method:                           MLE   Df Model:                           43
# Date:                Tue, 10 Jun 2025   Pseudo R-squ.:                  0.7042
# Time:                        09:25:12   Log-Likelihood:                -912.44
# converged:                       True   LL-Null:                       -3085.1
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.5519      0.128    -12.144      0.000      -1.802      -1.301
# X35            0.9643      0.309      3.121      0.002       0.359       1.570
# X51            0.3588      0.091      3.963      0.000       0.181       0.536
# X45           -1.4658      0.268     -5.470      0.000      -1.991      -0.941
# X46           -2.3563      1.793     -1.314      0.189      -5.871       1.158
# X27            0.4182      0.199      2.102      0.036       0.028       0.808
# X0            -0.4686      0.216     -2.173      0.030      -0.891      -0.046
# X43           -1.6193      0.535     -3.026      0.002      -2.668      -0.570
# X3             2.2568      1.507      1.497      0.134      -0.697       5.211
# X7             0.5645      0.166      3.395      0.001       0.239       0.890
# X56            0.0008      0.000      3.808      0.000       0.000       0.001
# X26          -11.2204      1.795     -6.250      0.000     -14.739      -7.702
# X18            0.0897      0.034      2.610      0.009       0.022       0.157
# X32           -0.7300      0.308     -2.370      0.018      -1.334      -0.126
# X48           -1.3093      0.447     -2.926      0.003      -2.186      -0.432
# X16            0.9452      0.221      4.280      0.000       0.512       1.378
# X1            -0.1372      0.065     -2.098      0.036      -0.265      -0.009
# X21            0.2210      0.165      1.341      0.180      -0.102       0.544
# X55            0.0104      0.002      5.836      0.000       0.007       0.014
# X24           -1.9811      0.313     -6.329      0.000      -2.595      -1.368
# X4             0.5656      0.102      5.560      0.000       0.366       0.765
# X40          -44.2004     26.428     -1.672      0.094     -95.999       7.598
# X22            2.1930      0.467      4.692      0.000       1.277       3.109
# X14            1.2934      0.703      1.841      0.066      -0.084       2.670
# X28           -2.5251      1.525     -1.656      0.098      -5.514       0.464
# X5             0.8248      0.245      3.371      0.001       0.345       1.304
# X53            2.2024      1.073      2.052      0.040       0.099       4.306
# X15            1.0484      0.145      7.250      0.000       0.765       1.332
# X38           -0.8670      0.383     -2.264      0.024      -1.617      -0.117
# X47           -4.0329      1.564     -2.579      0.010      -7.098      -0.968
# X19            1.1167      0.553      2.018      0.044       0.032       2.201
# X41           -2.6900      0.845     -3.184      0.001      -4.346      -1.034
# X25           -1.0360      0.440     -2.354      0.019      -1.899      -0.174
# X9             0.1161      0.070      1.659      0.097      -0.021       0.253
# X11           -0.1357      0.073     -1.851      0.064      -0.279       0.008
# X42           -1.2738      0.823     -1.548      0.122      -2.887       0.339
# X52            5.4814      0.706      7.762      0.000       4.097       6.866
# X8             0.6683      0.275      2.430      0.015       0.129       1.207
# X34           -2.1372      0.783     -2.729      0.006      -3.672      -0.602
# X44           -0.7956      0.155     -5.147      0.000      -1.099      -0.493
# X23            0.4424      0.169      2.618      0.009       0.111       0.774
# X6             2.2613      0.327      6.906      0.000       1.620       2.903
# X20            0.2330      0.049      4.714      0.000       0.136       0.330
# X37           -0.6061      0.427     -1.418      0.156      -1.444       0.232
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.28 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
