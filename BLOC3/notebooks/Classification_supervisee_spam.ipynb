# %% [markdown]
# ---
# # Machine learning : `spam`
# ---

# %% [markdown]
# ## Packages

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.inspection import permutation_importance
from sklearn.model_selection import GridSearchCV, train_test_split

from sklearn.ensemble import HistGradientBoostingClassifier, RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, plot_tree

from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

import time

# %% [markdown]
# ---
# ## 1. Données
# ---

# %% [markdown]
# ### 1.1. Importation

# %%
# En local :
directory = 'data/'

# Sur Google collab ou Onyxia (sur un répertoire temporaire) :
# directory = ''

# Sur Google collab (sur le drive) :
# from google.colab import drive
# drive.mount('/content/drive')
# directory = '/content/drive/MyDrive/Data/'

# %%
data = pd.read_csv(directory + 'spam.csv',
                   header    = 0,
                   index_col = 0,
                   sep       = ',',
                   decimal   = '.')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 4601 entries, 0.0 to 0.0
# Data columns (total 57 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   word_freq_address           4601 non-null   float64
#  1   word_freq_all               4601 non-null   float64
#  2   word_freq_3d                4601 non-null   float64
#  3   word_freq_our               4601 non-null   float64
#  4   word_freq_over              4601 non-null   float64
#  5   word_freq_remove            4601 non-null   float64
#  6   word_freq_internet          4601 non-null   float64
#  7   word_freq_order             4601 non-null   float64
#  8   word_freq_mail              4601 non-null   float64
#  9   word_freq_receive           4601 non-null   float64
#  10  word_freq_will              4601 non-null   float64
#  11  word_freq_people            4601 non-null   float64
#  12  word_freq_report            4601 non-null   float64
#  13  word_freq_addresses         4601 non-null   float64
#  14  word_freq_free              4601 non-null   float64
#  15  word_freq_business          4601 non-null   float64
#  16  word_freq_email             4601 non-null   float64
#  17  word_freq_you               4601 non-null   float64
#  18  word_freq_credit            4601 non-null   float64
#  19  word_freq_your              4601 non-null   float64
#  20  word_freq_font              4601 non-null   float64
#  21  word_freq_000               4601 non-null   float64
#  22  word_freq_money             4601 non-null   float64
#  23  word_freq_hp                4601 non-null   float64
#  24  word_freq_hpl               4601 non-null   float64
#  25  word_freq_george            4601 non-null   float64
#  26  word_freq_650               4601 non-null   float64
#  27  word_freq_lab               4601 non-null   float64
#  28  word_freq_labs              4601 non-null   float64
#  29  word_freq_telnet            4601 non-null   float64
#  30  word_freq_857               4601 non-null   float64
#  31  word_freq_data              4601 non-null   float64
#  32  word_freq_415               4601 non-null   float64
#  33  word_freq_85                4601 non-null   float64
#  34  word_freq_technology        4601 non-null   float64
#  35  word_freq_1999              4601 non-null   float64
#  36  word_freq_parts             4601 non-null   float64
#  37  word_freq_pm                4601 non-null   float64
#  38  word_freq_direct            4601 non-null   float64
#  39  word_freq_cs                4601 non-null   float64
#  40  word_freq_meeting           4601 non-null   float64
#  41  word_freq_original          4601 non-null   float64
#  42  word_freq_project           4601 non-null   float64
#  43  word_freq_re                4601 non-null   float64
#  44  word_freq_edu               4601 non-null   float64
#  45  word_freq_table             4601 non-null   float64
#  46  word_freq_conference        4601 non-null   float64
#  47  char_freq_semicolon         4601 non-null   float64
#  48  char_freq_leftbrac          4601 non-null   float64
#  49  char_freq_leftsquarebrac    4601 non-null   float64
#  50  char_freq_exclaim           4601 non-null   float64
#  51  char_freq_dollar            4601 non-null   float64
#  52  char_freq_pound             4601 non-null   float64
#  53  capital_run_length_average  4601 non-null   float64
#  54  capital_run_length_longest  4601 non-null   int64
#  55  capital_run_length_total    4601 non-null   int64
#  56  spam                        4601 non-null   int64
# dtypes: float64(54), int64(3)
# memory usage: 2.0 MB

# %%
data.head()
# Out:
#                 word_freq_address  word_freq_all  word_freq_3d  word_freq_our  \
# word_freq_make
# 0.00                         0.64           0.64           0.0           0.32
# 0.21                         0.28           0.50           0.0           0.14
# 0.06                         0.00           0.71           0.0           1.23
# 0.00                         0.00           0.00           0.0           0.63
# 0.00                         0.00           0.00           0.0           0.63
#
#                 word_freq_over  word_freq_remove  word_freq_internet  \
# word_freq_make
# 0.00                      0.00              0.00                0.00
# 0.21                      0.28              0.21                0.07
# 0.06                      0.19              0.19                0.12
# 0.00                      0.00              0.31                0.63
# 0.00                      0.00              0.31                0.63
#
#                 word_freq_order  word_freq_mail  word_freq_receive  ...  \
# word_freq_make                                                      ...
# 0.00                       0.00            0.00               0.00  ...
# 0.21                       0.00            0.94               0.21  ...
# 0.06                       0.64            0.25               0.38  ...
# 0.00                       0.31            0.63               0.31  ...
# 0.00                       0.31            0.63               0.31  ...
#
#                 char_freq_semicolon  char_freq_leftbrac  \
# word_freq_make
# 0.00                           0.00               0.000
# 0.21                           0.00               0.132
# 0.06                           0.01               0.143
# 0.00                           0.00               0.137
# 0.00                           0.00               0.135
#
#                 char_freq_leftsquarebrac  char_freq_exclaim  char_freq_dollar  \
# word_freq_make
# 0.00                                 0.0              0.778             0.000
# 0.21                                 0.0              0.372             0.180
# 0.06                                 0.0              0.276             0.184
# 0.00                                 0.0              0.137             0.000
# 0.00                                 0.0              0.135             0.000
#
#                 char_freq_pound  capital_run_length_average  \
# word_freq_make
# 0.00                      0.000                       3.756
# 0.21                      0.048                       5.114
# 0.06                      0.010                       9.821
# 0.00                      0.000                       3.537
# 0.00                      0.000                       3.537
#
#                 capital_run_length_longest  capital_run_length_total  spam
# word_freq_make
# 0.00                                    61                       278     1
# 0.21                                   101                      1028     1
# 0.06                                   485                      2259     1
# 0.00                                    40                       191     1
# 0.00                                    40                       191     1
#
# [5 rows x 57 columns]

# %% [markdown]
# ### 1.2. Gestion des données manquantes

# %%
missing_percentage = data.isna().mean() * 100

print('MISSING VALUES :')
if missing_percentage[missing_percentage != 0].empty:
    print('No')
else:
    print(missing_percentage[missing_percentage != 0].sort_values(ascending=False))
# Out:
# MISSING VALUES :
# No

# %% [markdown]
# ### 1.3. Gestion des variables

# %%
target = 'spam'
features = list(data.columns.difference([target]))

X = data[features]
y = data[target]

# %% [markdown]
# ### 1.4. Création d'un échantillon test

# %%
test_portion = 1/5

X_train_valid, X_test, y_train_valid, y_test = train_test_split(X, y, test_size=test_portion)

print('Dimensions X_train_valid :', X_train_valid.shape)
print('Dimensions X_test        :', X_test.shape)
print('Dimensions y_train_valid :', y_train_valid.shape)
print('Dimensions y_test        :', y_test.shape)
# Out:
# Dimensions X_train_valid : (3680, 56)
# Dimensions X_test        : (921, 56)
# Dimensions y_train_valid : (3680,)
# Dimensions y_test        : (921,)

# %% [markdown]
# ---
# ## 2. Modélisation
# ---

# %%
criteria = 'accuracy' # Pour le choix du critère CV (-MSE car GridSearchCV maximise le score)
n_folds  = 10                       # Pour le nombre de blocs CV (10)
n_core   = -1                       # Pour l'utilisation de tous les coeurs disponibles
verbose  = 1                        # Pour le caractère "verbeux"

# %% [markdown]
# ### 2.1. CART

# %%
start_time = time.time()

# %%
cart_model = DecisionTreeClassifier()
cart = cart_model.fit(X_train_valid, y_train_valid)

# %%
y_test_pred_cart = cart.predict(X_test)

# %%
end_time = time.time()
execution_time_cart = end_time - start_time
print(f"Temps d'exécution CART : {execution_time_cart:.2f} secondes")
# Out:
# Temps d'exécution CART : 0.09 secondes

# %%
cm_cart = confusion_matrix(y_test, y_test_pred_cart)
print("Matrice de confusion de l'arbre :\n", cm_cart)
# Accuracy
accuracy_cart = accuracy_score(y_test, y_test_pred_cart)
print(f"Accuracy : {accuracy_cart:.3f}")

# Precision
precision_cart = precision_score(y_test, y_test_pred_cart)
print(f"Precision : {precision_cart:.3f}")

# Sensibility (Recall)
sensibility_cart = recall_score(y_test, y_test_pred_cart)
print(f"Sensibility (Recall) : {sensibility_cart:.3f}")

# Specificity
tn, fp, fn, tp = cm_cart.ravel()
specificity_cart = tn / (tn + fp)
print(f"Specificity : {specificity_cart:.3f}")

# F1 Score
f1_cart = f1_score(y_test, y_test_pred_cart)
print(f"F1 Score : {f1_cart:.3f}")
# Out:
# Matrice de confusion de l'arbre :
#  [[505  42]
#  [ 44 330]]
# Accuracy : 0.907
# Precision : 0.887
# Sensibility (Recall) : 0.882
# Specificity : 0.923
# F1 Score : 0.885

# %% [markdown]
# ### 2.2. Random forest

# %%
start_time = time.time()

# %%
rf_model = RandomForestClassifier()

params_rf = {
    'n_estimators': [200, 300, 400, 500]
}

rf = GridSearchCV(estimator  = rf_model,
                  param_grid = params_rf,
                  scoring    = criteria,
                  cv         = n_folds,
                  n_jobs     = n_core,
                  verbose    = verbose)

rf.fit(X_train_valid, y_train_valid)
# Out:
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# GridSearchCV(cv=10, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'n_estimators': [200, 300, 400, 500]},
#              scoring='accuracy', verbose=1)

# %%
y_test_pred_rf = rf.predict(X_test)

# %%
end_time = time.time()
execution_time_rf = end_time - start_time
print(f"Temps d'exécution Random forest : {execution_time_rf:.2f} secondes")
# Out:
# Temps d'exécution Random forest : 12.36 secondes

# %%
print('Hyperparamètre optimal Random forest :', rf.best_params_)
# Out:
# Hyperparamètre optimal Random forest : {'n_estimators': 200}

# %%
cm_rf = confusion_matrix(y_test, y_test_pred_rf)
print("Matrice de confusion de l'arbre :\n", cm_rf)
# Accuracy
accuracy_rf = accuracy_score(y_test, y_test_pred_rf)
print(f"Accuracy : {accuracy_rf:.3f}")

# Precision
precision_rf = precision_score(y_test, y_test_pred_rf)
print(f"Precision : {precision_rf:.3f}")

# Sensibility (Recall)
sensibility_rf = recall_score(y_test, y_test_pred_rf)
print(f"Sensibility (Recall) : {sensibility_rf:.3f}")

# Specificity
tn, fp, fn, tp = cm_rf.ravel()
specificity_rf = tn / (tn + fp)
print(f"Specificity : {specificity_rf:.3f}")

# F1 Score
f1_rf = f1_score(y_test, y_test_pred_rf)
print(f"F1 Score : {f1_rf:.3f}")
# Out:
# Matrice de confusion de l'arbre :
#  [[530  17]
#  [ 21 353]]
# Accuracy : 0.959
# Precision : 0.954
# Sensibility (Recall) : 0.944
# Specificity : 0.969
# F1 Score : 0.949

# %% [markdown]
# On peut visualiser les résultats pour potentiellement réduire le nombre d'arbres choisi par validation croisée (si les performances sont proches) :

# %%
rf_out = pd.DataFrame(rf.cv_results_)
print(rf_out[['param_n_estimators', 'mean_test_score', 'std_test_score']])
# Out:
#   param_n_estimators  mean_test_score  std_test_score
# 0                200         0.953261        0.006291
# 1                300         0.951630        0.005408
# 2                400         0.951902        0.006772
# 3                500         0.951902        0.006320

# %% [markdown]
# On peut visualiser l'importance des variables :

# %%
perm_importance_rf = permutation_importance(rf.best_estimator_, X_train_valid, y_train_valid, scoring=criteria, n_repeats=10, n_jobs=n_core)

perm_importance_df = pd.DataFrame({
    'Variable': X_train_valid.columns,
    'Importance': perm_importance_rf.importances_mean
    }).sort_values(by='Importance', ascending=False)

plt.figure(figsize=(15, 15))
sns.barplot(x='Importance', y='Variable', data=perm_importance_df)
plt.xticks(rotation=45, ha='right')
plt.xlabel('Importance des variables (par permutation)')
plt.ylabel('Variable')
plt.title('Random forests')
plt.show()

# %% [markdown]
# ### 2.3. Gradient boosting

# %%
start_time = time.time()

# %%
gb_model = HistGradientBoostingClassifier(early_stopping=True, tol=1e-4)

params_gb = {
    'max_iter': [2000],
    'learning_rate': [0.05, 0.1, 0.15, 0.2, 0.25],
    'loss': ['log_loss'],
}

gb = GridSearchCV(estimator  = gb_model,
                  param_grid = params_gb,
                  scoring    = criteria,
                  cv         = n_folds,
                  n_jobs     = n_core,
                  verbose    = verbose)

gb.fit(X_train_valid, y_train_valid)
# Out:
# Fitting 10 folds for each of 5 candidates, totalling 50 fits
# GridSearchCV(cv=10,
#              estimator=HistGradientBoostingClassifier(early_stopping=True,
#                                                       tol=0.0001),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.05, 0.1, 0.15, 0.2, 0.25],
#                          'loss': ['log_loss'], 'max_iter': [2000]},
#              scoring='accuracy', verbose=1)

# %%
y_test_pred_gb = gb.predict(X_test)

# %%
end_time = time.time()
execution_time_gb = end_time - start_time
print(f"Temps d'exécution Gradient boosting : {execution_time_gb:.2f} secondes")
# Out:
# Temps d'exécution Gradient boosting : 4.34 secondes

# %%
print('Hyperparamètres optimaux Gradient boosting :', gb.best_params_)
print("Nombre d'itérations réel Gradient boosting :", gb.best_estimator_.n_iter_)
# Out:
# Hyperparamètres optimaux Gradient boosting : {'learning_rate': 0.15, 'loss': 'log_loss', 'max_iter': 2000}
# Nombre d'itérations réel Gradient boosting : 38

# %%
cm_gb = confusion_matrix(y_test, y_test_pred_gb)
print("Matrice de confusion de l'arbre :\n", cm_gb)
# Accuracy
accuracy_gb = accuracy_score(y_test, y_test_pred_gb)
print(f"Accuracy : {accuracy_gb:.3f}")

# Precision
precision_gb = precision_score(y_test, y_test_pred_gb)
print(f"Precision : {precision_gb:.3f}")

# Sensibility (Recall)
sensibility_gb = recall_score(y_test, y_test_pred_gb)
print(f"Sensibility (Recall) : {sensibility_gb:.3f}")

# Specificity
tn, fp, fn, tp = cm_gb.ravel()
specificity_gb = tn / (tn + fp)
print(f"Specificity : {specificity_gb:.3f}")

# F1 Score
f1_gb = f1_score(y_test, y_test_pred_gb)
print(f"F1 Score : {f1_gb:.3f}")
# Out:
# Matrice de confusion de l'arbre :
#  [[523  24]
#  [ 22 352]]
# Accuracy : 0.950
# Precision : 0.936
# Sensibility (Recall) : 0.941
# Specificity : 0.956
# F1 Score : 0.939

# %% [markdown]
# ---
# ## 3. Synthèse
# ---

# %%
metrics = ['Accuracy', 'Precision', 'Sensibility', 'Specificity', 'F1', 'Temps d\'exécution']
models = ['CART', 'Random forest', 'Gradient Boosting']

values = [
    [accuracy_cart, precision_cart, sensibility_cart, specificity_cart, f1_cart, execution_time_cart],
    [accuracy_rf, precision_rf, sensibility_rf, specificity_rf, f1_rf, execution_time_rf],
    [accuracy_gb, precision_gb, sensibility_gb, specificity_gb, f1_gb, execution_time_gb],
]

values = np.array(values)

fig, ax = plt.subplots(figsize=(10, 6))
bar_width = 0.2
x = np.arange(len(metrics))

for i, model in enumerate(models):
    ax.bar(x + i * bar_width, values[i], width=bar_width, label=model)

ax.set_xticks(x + bar_width)
ax.set_xticklabels(metrics)
ax.set_ylabel('Score')
ax.set_title('Comparaison des métriques des modèles')
ax.legend()
ax.set_yscale('log')
plt.show()
