# %% [markdown]
# ---
# # DNN : `spam` (avec `Keras`, version de base)
# ---

# %% [markdown]
# ## Packages

# %%
import pandas as pd

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from keras import layers, models
# Out:
# 2025-10-01 12:56:34.267636: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-01 12:56:34.334694: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-01 12:56:36.014943: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %% [markdown]
# ---
# ## 1. Données
# ---

# %% [markdown]
# ### 1.1. Importation

# %%
# En local :
directory = 'data/'

# Sur Google collab ou Onyxia (sur un répertoire temporaire) :
# directory = ''

# Sur Google collab (sur le drive) :
# from google.colab import drive
# drive.mount('/content/drive')
# directory = '/content/drive/MyDrive/Data/'

# %%
data = pd.read_csv(directory + 'spam.csv',
                   header    = 0,
                   # index_col = 0,
                   sep       = ',',
                   decimal   = '.')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4601 entries, 0 to 4600
# Data columns (total 58 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   word_freq_make              4601 non-null   float64
#  1   word_freq_address           4601 non-null   float64
#  2   word_freq_all               4601 non-null   float64
#  3   word_freq_3d                4601 non-null   float64
#  4   word_freq_our               4601 non-null   float64
#  5   word_freq_over              4601 non-null   float64
#  6   word_freq_remove            4601 non-null   float64
#  7   word_freq_internet          4601 non-null   float64
#  8   word_freq_order             4601 non-null   float64
#  9   word_freq_mail              4601 non-null   float64
#  10  word_freq_receive           4601 non-null   float64
#  11  word_freq_will              4601 non-null   float64
#  12  word_freq_people            4601 non-null   float64
#  13  word_freq_report            4601 non-null   float64
#  14  word_freq_addresses         4601 non-null   float64
#  15  word_freq_free              4601 non-null   float64
#  16  word_freq_business          4601 non-null   float64
#  17  word_freq_email             4601 non-null   float64
#  18  word_freq_you               4601 non-null   float64
#  19  word_freq_credit            4601 non-null   float64
#  20  word_freq_your              4601 non-null   float64
#  21  word_freq_font              4601 non-null   float64
#  22  word_freq_000               4601 non-null   float64
#  23  word_freq_money             4601 non-null   float64
#  24  word_freq_hp                4601 non-null   float64
#  25  word_freq_hpl               4601 non-null   float64
#  26  word_freq_george            4601 non-null   float64
#  27  word_freq_650               4601 non-null   float64
#  28  word_freq_lab               4601 non-null   float64
#  29  word_freq_labs              4601 non-null   float64
#  30  word_freq_telnet            4601 non-null   float64
#  31  word_freq_857               4601 non-null   float64
#  32  word_freq_data              4601 non-null   float64
#  33  word_freq_415               4601 non-null   float64
#  34  word_freq_85                4601 non-null   float64
#  35  word_freq_technology        4601 non-null   float64
#  36  word_freq_1999              4601 non-null   float64
#  37  word_freq_parts             4601 non-null   float64
#  38  word_freq_pm                4601 non-null   float64
#  39  word_freq_direct            4601 non-null   float64
#  40  word_freq_cs                4601 non-null   float64
#  41  word_freq_meeting           4601 non-null   float64
#  42  word_freq_original          4601 non-null   float64
#  43  word_freq_project           4601 non-null   float64
#  44  word_freq_re                4601 non-null   float64
#  45  word_freq_edu               4601 non-null   float64
#  46  word_freq_table             4601 non-null   float64
#  47  word_freq_conference        4601 non-null   float64
#  48  char_freq_semicolon         4601 non-null   float64
#  49  char_freq_leftbrac          4601 non-null   float64
#  50  char_freq_leftsquarebrac    4601 non-null   float64
#  51  char_freq_exclaim           4601 non-null   float64
#  52  char_freq_dollar            4601 non-null   float64
#  53  char_freq_pound             4601 non-null   float64
#  54  capital_run_length_average  4601 non-null   float64
#  55  capital_run_length_longest  4601 non-null   int64
#  56  capital_run_length_total    4601 non-null   int64
#  57  spam                        4601 non-null   int64
# dtypes: float64(55), int64(3)
# memory usage: 2.0 MB

# %%
data.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.00               0.64           0.64           0.0
# 1            0.21               0.28           0.50           0.0
# 2            0.06               0.00           0.71           0.0
# 3            0.00               0.00           0.00           0.0
# 4            0.00               0.00           0.00           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.32            0.00              0.00                0.00
# 1           0.14            0.28              0.21                0.07
# 2           1.23            0.19              0.19                0.12
# 3           0.63            0.00              0.31                0.63
# 4           0.63            0.00              0.31                0.63
#
#    word_freq_order  word_freq_mail  ...  char_freq_semicolon  \
# 0             0.00            0.00  ...                 0.00
# 1             0.00            0.94  ...                 0.00
# 2             0.64            0.25  ...                 0.01
# 3             0.31            0.63  ...                 0.00
# 4             0.31            0.63  ...                 0.00
#
#    char_freq_leftbrac  char_freq_leftsquarebrac  char_freq_exclaim  \
# 0               0.000                       0.0              0.778
# 1               0.132                       0.0              0.372
# 2               0.143                       0.0              0.276
# 3               0.137                       0.0              0.137
# 4               0.135                       0.0              0.135
#
#    char_freq_dollar  char_freq_pound  capital_run_length_average  \
# 0             0.000            0.000                       3.756
# 1             0.180            0.048                       5.114
# 2             0.184            0.010                       9.821
# 3             0.000            0.000                       3.537
# 4             0.000            0.000                       3.537
#
#    capital_run_length_longest  capital_run_length_total  spam
# 0                          61                       278     1
# 1                         101                      1028     1
# 2                         485                      2259     1
# 3                          40                       191     1
# 4                          40                       191     1
#
# [5 rows x 58 columns]

# %% [markdown]
# ### 1.2. Gestion des données manquantes

# %%
missing_percentage = data.isna().mean() * 100

print('MISSING VALUES :')
if missing_percentage[missing_percentage != 0].empty:
    print('No')
else:
    print(missing_percentage[missing_percentage != 0].sort_values(ascending=False))
# Out:
# MISSING VALUES :
# No

# %% [markdown]
# ### 1.3. Gestion des variables

# %%
target = 'spam'

y = data[target]
X = data.drop(target, axis=1)

# %% [markdown]
# ### 1.4. Création des échantillons de validation et test

# %%
test_portion  = 1/5
valid_portion = 1/5

X_train_valid, X_test, y_train_valid, y_test = train_test_split(X, y, test_size=test_portion)

X_train, X_valid, y_train, y_valid = train_test_split(X_train_valid, y_train_valid, test_size=valid_portion)

print('Dimensions de X_train :', X_train.shape)
print('Dimensions de X_valid :', X_valid.shape)
print('Dimensions de X_test  :', X_test.shape)

print('Dimensions de y_train :', y_train.shape)
print('Dimensions de y_valid :', y_valid.shape)
print('Dimensions de y_test  :', y_test.shape)
# Out:
# Dimensions de X_train : (2944, 57)
# Dimensions de X_valid : (736, 57)
# Dimensions de X_test  : (921, 57)
# Dimensions de y_train : (2944,)
# Dimensions de y_valid : (736,)
# Dimensions de y_test  : (921,)

# %% [markdown]
# ### 1.5. Normalisation des covariables

# %% [markdown]
# On normalise (centrage-réduction) les covariables :

# %%
scaler = StandardScaler()
scaler.fit(X_train)

X_train_norm = scaler.transform(X_train)
X_valid_norm = scaler.transform(X_valid)
X_test_norm  = scaler.transform(X_test)

# %% [markdown]
# ---
# ## 2. DNN
# ---

# %% [markdown]
# ### 2.1. Architecture

# %%
dim_inputs  = (X_train_norm.shape[1],)
dim_outputs = 1

n_units_hl1 = 50
n_units_hl2 = 30

model = models.Sequential(name='DNN')

model.add(layers.Input(shape=dim_inputs, name='Inputs'))

model.add(layers.Dense(units=n_units_hl1, activation='relu', name='Hidden_layer_1'))

model.add(layers.Dense(units=n_units_hl2, activation='relu', name='Hidden_layer_2'))

model.add(layers.Dense(units=dim_outputs, activation='sigmoid', name='Output_layer'))

model.summary()
# Out:
# 2025-10-01 12:58:02.612451: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "DNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Hidden_layer_1 (Dense)          │ (None, 50)             │         2,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden_layer_2 (Dense)          │ (None, 30)             │         1,530 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output_layer (Dense)            │ (None, 1)              │            31 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,461 (17.43 KB)
#  Trainable params: 4,461 (17.43 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 2.2. Optimiseur

# %%
model.compile(optimizer = 'adam',
              loss      = 'binary_crossentropy',
              metrics   = ['accuracy'])

# %% [markdown]
# ### 2.3. Entraînement

# %%
hist = model.fit(X_train_norm,
                 y_train,
                 batch_size      = 500,
                 epochs          = 200,
                 validation_data = (X_valid_norm, y_valid),
                 verbose         = 1)
# Out:
# Epoch 1/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.4477 - loss: 0.7683 - val_accuracy: 0.5883 - val_loss: 0.6888
# Epoch 2/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.6647 - loss: 0.6457 - val_accuracy: 0.7418 - val_loss: 0.5984
# Epoch 3/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7714 - loss: 0.5619 - val_accuracy: 0.7826 - val_loss: 0.5326
# Epoch 4/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8128 - loss: 0.4962 - val_accuracy: 0.8111 - val_loss: 0.4762
# Epoch 5/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 0.8495 - loss: 0.4395 - val_accuracy: 0.8410 - val_loss: 0.4248
# Epoch 6/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8709 - loss: 0.3909 - val_accuracy: 0.8641 - val_loss: 0.3795
# Epoch 7/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8852 - loss: 0.3491 - val_accuracy: 0.8804 - val_loss: 0.3425
# Epoch 8/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.8957 - loss: 0.3160 - val_accuracy: 0.8899 - val_loss: 0.3128
# Epoch 9/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9018 - loss: 0.2898 - val_accuracy: 0.8981 - val_loss: 0.2899
# Epoch 10/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.9056 - loss: 0.2701 - val_accuracy: 0.9022 - val_loss: 0.2714
# Epoch 11/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9107 - loss: 0.2542 - val_accuracy: 0.9090 - val_loss: 0.2570
# Epoch 12/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9154 - loss: 0.2422 - val_accuracy: 0.9185 - val_loss: 0.2453
# Epoch 13/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9178 - loss: 0.2317 - val_accuracy: 0.9226 - val_loss: 0.2351
# Epoch 14/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9215 - loss: 0.2229 - val_accuracy: 0.9293 - val_loss: 0.2269
# Epoch 15/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9239 - loss: 0.2154 - val_accuracy: 0.9293 - val_loss: 0.2201
# Epoch 16/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9246 - loss: 0.2087 - val_accuracy: 0.9307 - val_loss: 0.2143
# Epoch 17/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9263 - loss: 0.2027 - val_accuracy: 0.9334 - val_loss: 0.2093
# Epoch 18/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9276 - loss: 0.1968 - val_accuracy: 0.9321 - val_loss: 0.2046
# Epoch 19/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.
200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9925 - loss: 0.0312 - val_accuracy: 0.9361 - val_loss: 0.2581
# Epoch 180/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.9925 - loss: 0.0305 - val_accuracy: 0.9375 - val_loss: 0.2567
# Epoch 181/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.9918 - loss: 0.0306 - val_accuracy: 0.9361 - val_loss: 0.2587
# Epoch 182/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.9922 - loss: 0.0301 - val_accuracy: 0.9361 - val_loss: 0.2601
# Epoch 183/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9918 - loss: 0.0303 - val_accuracy: 0.9348 - val_loss: 0.2630
# Epoch 184/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9918 - loss: 0.0300 - val_accuracy: 0.9375 - val_loss: 0.2633
# Epoch 185/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.9925 - loss: 0.0292 - val_accuracy: 0.9361 - val_loss: 0.2660
# Epoch 186/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.9925 - loss: 0.0293 - val_accuracy: 0.9375 - val_loss: 0.2674
# Epoch 187/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9932 - loss: 0.0285 - val_accuracy: 0.9348 - val_loss: 0.2682
# Epoch 188/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9935 - loss: 0.0291 - val_accuracy: 0.9375 - val_loss: 0.2686
# Epoch 189/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9922 - loss: 0.0292 - val_accuracy: 0.9375 - val_loss: 0.2697
# Epoch 190/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.9929 - loss: 0.0282 - val_accuracy: 0.9361 - val_loss: 0.2710
# Epoch 191/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.9935 - loss: 0.0275 - val_accuracy: 0.9389 - val_loss: 0.2725
# Epoch 192/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9929 - loss: 0.0277 - val_accuracy: 0.9348 - val_loss: 0.2733
# Epoch 193/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9932 - loss: 0.0275 - val_accuracy: 0.9361 - val_loss: 0.2756
# Epoch 194/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9932 - loss: 0.0270 - val_accuracy: 0.9361 - val_loss: 0.2757
# Epoch 195/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9932 - loss: 0.0267 - val_accuracy: 0.9348 - val_loss: 0.2773
# Epoch 196/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9935 - loss: 0.0263 - val_accuracy: 0.9375 - val_loss: 0.2798
# Epoch 197/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.9932 - loss: 0.0263 - val_accuracy: 0.9389 - val_loss: 0.2796
# Epoch 198/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9935 - loss: 0.0261 - val_accuracy: 0.9375 - val_loss: 0.2801
# Epoch 199/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9939 - loss: 0.0257 - val_accuracy: 0.9375 - val_loss: 0.2824
# Epoch 200/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9935 - loss: 0.0258 - val_accuracy: 0.9375 - val_loss: 0.2847

# %%
fig, ax = plt.subplots(figsize=(10, 7))
ax.plot(hist.history['loss'], label='Train')
ax.plot(hist.history['val_loss'], label='Validation')
ax.set_xlabel('Epoque')
ax.set_title('Entropie')
ax.legend(loc='best')
plt.show()

# %% [markdown]
# Pas bon, on a surappris. Ce code n'est pas utilisable. Il faut ajouter un callback.

# %%
fig, ax = plt.subplots(figsize=(10, 7))
ax.plot(hist.history['accuracy'], label='Train')
ax.plot(hist.history['val_accuracy'], label='Validation')
ax.set_xlabel('Epoque')
ax.set_title('Exactitude (accuracy)')
ax.legend(loc='best')
plt.show()

# %% [markdown]
# ### 2.4. Prévisions

# %%
y_test_pred = model.predict(X_test_norm)
y_test_pred[0:5]
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# array([[1.1205102e-05],
#        [1.5513985e-09],
#        [8.9064270e-05],
#        [1.9497784e-05],
#        [2.9103333e-02]], dtype=float32)

# %%
y_test_pred_classes = (y_test_pred > 0.5).astype(int)
y_test_pred_classes[0:5]
# Out:
# array([[0],
#        [0],
#        [0],
#        [0],
#        [0]])

# %%
score_test = model.evaluate(X_test_norm, y_test, verbose=0)
print(f'Entropie test   : {score_test[0]:4.4f}')
print(f'Exactitude test : {score_test[1]:4.4f}')
# Out:
# Entropie test   : 0.2709
# Exactitude test : 0.9392
